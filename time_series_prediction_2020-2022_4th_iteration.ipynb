# %%
import pandas as pd
import os
from itables import show
import numpy as np
import matplotlib.pyplot as plt
import sklearn
from sklearn.preprocessing import MinMaxScaler

# %%
#finding out how many cpu cores you have
# !wmic cpu get NumberOfCores,NumberOfLogicalProcessors

#divide the work between the existing cores - 1
os.environ['OMP_NUM_THREADS']='7'
# Out:
# NumberOfCores  NumberOfLogicalProcessors
#
# 4              8

# %% [markdown]
# # Prepare data set for prediction

# %%
traffic = pd.read_csv('traffic_2020-2022_orientation.csv')
weather = pd.read_csv('weather_data_hourly.csv')
emissions = pd.read_csv('emission_huegelstr_hourly.csv')

# %%
pred_data = traffic.merge(weather, how='left', on= 'timestamp').merge(emissions[['PM10','PM2,5', 'NO2','timestamp']], how='left', on= 'timestamp')
show(pred_data)

df = pred_data.copy()
# Out:
# <style>.itables table td {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables table th {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables thead input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
#
# .itables tfoot input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
# </style>
# <div class="itables">
# <table id="0f05c018-14b0-446a-9cb1-bcb6fb5b41f6" class="display nowrap"style="table-layout:auto;width:auto;margin:auto;caption-side:bottom"><thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>timestamp</th>
#       <th>east inbound</th>
#       <th>north inbound</th>
#       <th>south inbound</th>
#       <th>west inbound</th>
#       <th>east outbound</th>
#       <th>north outbound</th>
#       <th>south outbound</th>
#       <th>west outbound</th>
#       <th>Luftdruck[hPa]</th>
#       <th>Relative Luftfeuchtigkeit[%]</th>
#       <th>Temperatur[°C]</th>
#       <th>Windgeschwindigkeit[m/s]</th>
#       <th>Windrichtung[Grad]</th>
#       <th>PM10</th>
#       <th>PM2,5</th>
#       <th>NO2</th>
#     </tr>
#   </thead><tbody><tr><td>Loading... (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td></tr></tbody></table>
# <link rel="stylesheet" type="text/css" href="https://cdn.datatables.net/1.13.1/css/jquery.dataTables.min.css">
# <script type="module">
#     // Import jquery and DataTable
#     import 'https://code.jquery.com/jquery-3.6.0.min.js';
#     import dt from 'https://cdn.datatables.net/1.12.1/js/jquery.dataTables.mjs';
#     dt($);
#
#     // Define the table data
#     const data = [[0, "2020-06-01 00:00:00", 153.0, 232.0, 224.0, 275.0, 28.0, 206.2, 185.0, 1346.31, 1021.0, 72.75, 13.1, 0.6, 96.0, 9.25, 4.75, 9.7], [1, "2020-06-01 01:00:00", 87.0, 154.4, 142.0, 54.0, 15.0, 125.4, 116.0, 406.9, 1022.0, 81.75, 10.75, 0.4, 112.0, 5.65, 3.25, 10.05], [2, "2020-06-01 02:00:00", 56.0, 84.8, 83.0, 25.0, 16.0, 52.0, 68.0, 243.41, 1022.0, 93.05, 9.35, 0.45, 76.5, 5.05, 3.05, 11.4], [3, "2020-06-01 03:00:00", 39.0, 52.6, 43.0, 15.0, 3.0, 53.4, 42.0, 272.47, 1022.0, 96.55, 8.4, 0.55, 71.5, 6.25, 3.35, 11.1], [4, "2020-06-01 04:00:00", 12.0, 72.5, 50.0, 11.0, 4.0, 38.4, 33.0, 413.96, 1022.0, 98.55, 7.8, 0.4, 111.5, 6.0, 3.35, 9.65], [5, "2020-06-01 05:00:00", 90.0, 147.5, 100.0, 137.0, 8.0, 72.4, 44.0, 1260.45, 1022.0, 97.25, 8.15, 0.5, 110.0, 6.5, 3.85, 13.0], [6, "2020-06-01 06:00:00", 94.0, 130.7, 98.0, 204.0, 16.0, 77.6, 90.0, 1530.86, 1022.0, 86.2, 10.9, 1.05, 52.0, 6.1, 3.65, 8.8], [7, "2020-06-01 07:00:00", 108.0, 141.7, 127.0, 217.0, 17.0, 107.8, 89.0, 1539.37, 1022.0, 71.9, 13.45, 1.4, 41.5, 6.3, 3.25, 6.3], [8, "2020-06-01 08:00:00", 157.0, 216.8, 208.0, 279.0, 48.0, 161.2, 168.0, 1491.31, 1022.0, 62.55, 15.8, 1.6, 48.5, 8.75, 3.6, 5.45], [9, "2020-
# 2020-06-01 07:00:00                41.5   6.30   3.25   6.30
# 2020-06-01 08:00:00                48.5   8.75   3.60   5.45
# 2020-06-01 09:00:00                60.0  11.85   4.60   5.65
# 2020-06-01 10:00:00                63.5  13.10   5.20   6.50
# 2020-06-01 11:00:00                64.0  14.55   5.45   6.60
# 2020-06-01 12:00:00                72.0  15.55   6.05  11.65
# 2020-06-01 13:00:00                86.5  12.85   5.35  10.30
# 2020-06-01 14:00:00               115.0  12.65   5.30  18.15
# 2020-06-01 15:00:00                92.5  12.55   5.25  21.20
# 2020-06-01 16:00:00                72.5  11.65   4.90  20.10
# 2020-06-01 17:00:00                96.0  11.75   4.90  27.15
# 2020-06-01 18:00:00                70.0  13.40   5.15  25.60
# 2020-06-01 19:00:00                92.5  14.85   6.70  44.55
# 2020-06-01 20:00:00                65.0  16.10   8.45  64.00
# 2020-06-01 21:00:00                65.5  15.05   7.40  44.70
# 2020-06-01 22:00:00                99.0  13.85   6.90  19.15
# 2020-06-01 23:00:00               101.0  12.15   6.55  10.85
# 2020-06-02 00:00:00                74.5  12.50   6.15  11.50
# 2020-06-02 01:00:00                60.5  13.60   6.25   8.35

# %% [markdown]
# # Univariate Time Series Forecasting (LSTM)

# %%
emissions = df['PM10']
emissions.plot()
# Out:
# <Axes: xlabel='timestamp'>

# %%
# [[[1], [2], [3], [4], [5]]] [6]
# [[[2], [3], [4], [5], [6]]] [7]
# [[[3], [4], [5], [6], [7]]] [8]

def df_to_X_y(df, window_size=5):
  df_as_np = df.to_numpy()
  X = []
  y = []
  for i in range(len(df_as_np)-window_size):
    row = [[a] for a in df_as_np[i:i+window_size]]
    X.append(row)
    label = df_as_np[i+window_size]
    y.append(label)
  return np.array(X), np.array(y)

# %%
WINDOW_SIZE = 5
X1, y1 = df_to_X_y(emissions, WINDOW_SIZE)
X1.shape, y1.shape
# Out:
# ((5827, 5, 1), (5827,))

# %%
X_train1, y_train1 = X1[:4000], y1[:4000]
X_val1, y_val1 = X1[4000:4800], y1[4000:4800]
X_test1, y_test1 = X1[4800:], y1[4800:]
X_train1.shape, y_train1.shape, X_val1.shape, y_val1.shape, X_test1.shape, y_test1.shape
# Out:
# ((4000, 5, 1), (4000,), (800, 5, 1), (800,), (1027, 5, 1), (1027,))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam

model1 = Sequential()
model1.add(InputLayer((5, 1)))
model1.add(LSTM(64))
model1.add(Dense(8, 'relu'))
model1.add(Dense(1, 'linear'))

model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 64)                16896
#
#  dense (Dense)               (None, 8)                 520
#
#  dense_1 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 17,425
# Trainable params: 17,425
# Non-trainable params: 0
# _________________________________________________________________

# %%
cp1 = ModelCheckpoint('model1/', save_best_only=True)
model1.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
model1.fit(X_train1, y_train1, validation_data=(X_val1, y_val1), epochs=10, callbacks=[cp1])
# Out:
# Epoch 1/10
# 121/125 [============================>.] - ETA: 0s - loss: 256.1839 - root_mean_squared_error: 16.0057
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# 125/125 [==============================] - 22s 141ms/step - loss: 254.6886 - root_mean_squared_error: 15.9590 - val_loss: 238.3633 - val_root_mean_squared_error: 15.4390
# Epoch 2/10
# 116/125 [==========================>...] - ETA: 0s - loss: 196.2001 - root_mean_squared_error: 14.0071
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# 125/125 [==============================] - 13s 105ms/step - loss: 193.2422 - root_mean_squared_error: 13.9012 - val_loss: 172.1383 - val_root_mean_squared_error: 13.1201
# Epoch 3/10
# 116/125 [==========================>...] - ETA: 0s - loss: 135.1630 - root_mean_squared_error: 11.6260
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# 125/125 [==============================] - 15s 124ms/step - loss: 134.1337 - root_mean_squared_error: 11.5816 - val_loss: 122.2984 - val_root_mean_squared_error: 11.0589
# Epoch 4/10
# 124/125 [============================>.] - ETA: 0s - loss: 100.8133 - root_mean_squared_error: 10.0406
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# 125/125 [==============================] - 18s 143ms/step - loss: 100.7765 - root_mean_squared_error: 10.0388 - val_loss: 99.8970 - val_root_mean_squared_error: 9.9948
# Epoch 5/10
# 124/125 [============================>.] - ETA: 0s - loss: 86.5703 - root_mean_squared_error: 9.3043
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# 125/125 [==============================] - 16s 126ms/step - loss: 86.8760 - root_mean_squared_error: 9.3207 - val_loss: 89.6850 - val_root_mean_squared_error: 9.4702
# Epoch 6/10
# 124/125 [============================>.] - ETA: 0s - loss: 79.9897 - root_mean_squared_error: 8.9437
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# 125/125 [==============================] - 20s 163ms/step - loss: 79.5814 - root_mean_squared_error: 8.9208 - val_loss: 82.6067 - val_root_mean_squared_error: 9.0888
# Epoch 7/10
# 119/125 [===========================>..] - ETA: 0s - loss: 74.5821 - root_mean_squared_error: 8.6361
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# 125/125 [==============================] - 17s 133ms/step - loss: 73.6681 - root_mean_squared_error: 8.5830 - val_loss: 75.9647 - val_root_mean_squared_error: 8.7158
# Epoch 8/10
# 122/125 [============================>.] - ETA: 0s - loss: 68.3043 - root_mean_squared_error: 8.2646
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# 125/125 [==============================] - 17s 138ms/step - loss: 67.8886 - root_mean_squared_error: 8.2395 - val_loss: 70.3923 - val_root_mean_squared_error: 8.3900
# Epoch 9/10
# 122/125 [============================>.] - ETA: 0s - loss: 62.4827 - root_mean_squared_error: 7.9046
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# 125/125 [==============================] - 17s 140ms/step - loss: 62.7549 - root_mean_squared_error: 7.9218 - val_loss: 64.8969 - val_root_mean_squared_error: 8.0559
# Epoch 10/10
# 118/125 [===========================>..] - ETA: 0s - loss: 59.1280 - root_mean_squared_error: 7.6895
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# 125/125 [==============================] - 22s 176ms/step - loss: 58.7959 - root_mean_squared_error: 7.6678 - val_loss: 61.1792 - val_root_mean_squared_error: 7.8217

# %%
from tensorflow.keras.models import load_model
model1 = load_model('model1/')

# %%
train_predictions = model1.predict(X_train1).flatten()
train_results = pd.DataFrame(data={'Train Predictions':train_predictions, 'Actuals':y_train1})
train_results
# Out:
# 125/125 [==============================] - 2s 6ms/step
#       Train Predictions  Actuals
# 0             13.622010     11.6
# 1             12.852242     11.3
# 2             12.448582     14.6
# 3             14.167357     19.6
# 4             16.603041     23.2
# ...                 ...      ...
# 3995          16.614370     17.7
# 3996          16.728550     17.9
# 3997          16.839226     17.8
# 3998          16.841763     13.4
# 3999          15.013018     13.2
#
# [4000 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
plt.plot(train_results['Train Predictions'][50:100])
plt.plot(train_results['Actuals'][50:100])

# %%
val_predictions = model1.predict(X_val1).flatten()
val_results = pd.DataFrame(data={'Val Predictions':val_predictions, 'Actuals':y_val1})
val_results
# Out:
# 25/25 [==============================] - 0s 8ms/step
#      Val Predictions  Actuals
# 0          14.263607     19.2
# 1          16.511623     17.4
# 2          16.495144     17.5
# 3          16.678539     29.1
# 4          18.428648     30.4
# ..               ...      ...
# 795        16.460543     16.3
# 796        16.187681     10.4
# 797        13.122576      9.6
# 798        12.028946     10.5
# 799        11.949796     11.8
#
# [800 rows x 2 columns]

# %%
plt.plot(val_results['Val Predictions'][:100])
plt.plot(val_results['Actuals'][:100])

# %%
test_predictions = model1.predict(X_test1).flatten()
test_results = pd.DataFrame(data={'Test Predictions':test_predictions, 'Actuals':y_test1})
test_results
# Out:
# 33/33 [==============================] - 1s 4ms/step
#       Test Predictions  Actuals
# 0            12.458536     13.0
# 1            13.327362     11.8
# 2            12.998719     13.1
# 3            13.579942     14.8
# 4            14.517666     14.5
# ...                ...      ...
# 1022         11.349430     10.9
# 1023         11.990904     10.8
# 1024         12.349892      7.7
# 1025         11.161692      7.6
# 1026         10.560867     10.5
#
# [1027 rows x 2 columns]

# %%
plt.plot(test_results['Test Predictions'][:100])
plt.plot(test_results['Actuals'][:100])

# %% [markdown]
# ## Convolutional Neural Network

# %%
model2 = Sequential()
model2.add(InputLayer((5, 1)))
model2.add(Conv1D(64, kernel_size=2))
model2.add(Flatten())
model2.add(Dense(8, 'relu'))
model2.add(Dense(1, 'linear'))

model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 4, 64)             192
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense_2 (Dense)             (None, 8)                 2056
#
#  dense_3 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 2,257
# Trainable params: 2,257
# Non-trainable params: 0
# _________________________________________________________________

# %%
cp2 = ModelCheckpoint('model2/', save_best_only=True)
model2.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
model2.fit(X_train1, y_train1, validation_data=(X_val1, y_val1), epochs=10, callbacks=[cp2])
# Out:
# Epoch 1/10
# 117/125 [===========================>..] - ETA: 0s - loss: 189.3554 - root_mean_squared_error: 13.7606
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# 125/125 [==============================] - 5s 34ms/step - loss: 183.3951 - root_mean_squared_error: 13.5423 - val_loss: 91.6827 - val_root_mean_squared_error: 9.5751
# Epoch 2/10
# 121/125 [============================>.] - ETA: 0s - loss: 75.1201 - root_mean_squared_error: 8.6672
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# 125/125 [==============================] - 2s 17ms/step - loss: 74.9463 - root_mean_squared_error: 8.6572 - val_loss: 68.0379 - val_root_mean_squared_error: 8.2485
# Epoch 3/10
# 118/125 [===========================>..] - ETA: 0s - loss: 59.0765 - root_mean_squared_error: 7.6861
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# 125/125 [==============================] - 3s 24ms/step - loss: 59.4301 - root_mean_squared_error: 7.7091 - val_loss: 56.2023 - val_root_mean_squared_error: 7.4968
# Epoch 4/10
# 125/125 [==============================] - ETA: 0s - loss: 50.3884 - root_mean_squared_error: 7.0985
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# 125/125 [==============================] - 3s 21ms/step - loss: 50.3884 - root_mean_squared_error: 7.0985 - val_loss: 49.1613 - val_root_mean_squared_error: 7.0115
# Epoch 5/10
# 125/125 [==============================] - ETA: 0s - loss: 44.9420 - root_mean_squared_error: 6.7039
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# 125/125 [==============================] - 3s 26ms/step - loss: 44.9420 - root_mean_squared_error: 6.7039 - val_loss: 45.0698 - val_root_mean_squared_error: 6.7134
# Epoch 6/10
# 107/125 [========================>.....] - ETA: 0s - loss: 41.5436 - root_mean_squared_error: 6.4454
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# 125/125 [==============================] - 3s 24ms/step - loss: 41.7826 - root_mean_squared_error: 6.4639 - val_loss: 43.0783 - val_root_mean_squared_error: 6.5634
# Epoch 7/10
# 124/125 [============================>.] - ETA: 0s - loss: 40.0119 - root_mean_squared_error: 6.3255
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# 125/125 [==============================] - 3s 24ms/step - loss: 40.0868 - root_mean_squared_error: 6.3314 - val_loss: 41.3868 - val_root_mean_squared_error: 6.4333
# Epoch 8/10
# 111/125 [=========================>....] - ETA: 0s - loss: 37.5211 - root_mean_squared_error: 6.1254
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# 125/125 [==============================] - 3s 20ms/step - loss: 39.0336 - root_mean_squared_error: 6.2477 - val_loss: 40.5175 - val_root_mean_squared_error: 6.3653
# Epoch 9/10
# 114/125 [==========================>...] - ETA: 0s - loss: 39.0350 - root_mean_squared_error: 6.2478
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# 125/125 [==============================] - 3s 26ms/step - loss: 38.3272 - root_mean_squared_error: 6.1909 - val_loss: 39.9356 - val_root_mean_squared_error: 6.3195
# Epoch 10/10
# 122/125 [============================>.] - ETA: 0s - loss: 38.2703 - root_mean_squared_error: 6.1863
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# 125/125 [==============================] - 3s 21ms/step - loss: 37.9420 - root_mean_squared_error: 6.1597 - val_loss: 39.5050 - val_root_mean_squared_error: 6.2853

# %% [markdown]
# ## GRU (Gated Recurrent Unit)

# %%
model3 = Sequential()
model3.add(InputLayer((5, 1)))
model3.add(GRU(64))
model3.add(Dense(8, 'relu'))
model3.add(Dense(1, 'linear'))
model3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 64)                12864
#
#  dense_4 (Dense)             (None, 8)                 520
#
#  dense_5 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 13,393
# Trainable params: 13,393
# Non-trainable params: 0
# _________________________________________________________________

# %%
cp3 = ModelCheckpoint('model3/', save_best_only=True)
model3.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
model3.fit(X_train1, y_train1, validation_data=(X_val1, y_val1), epochs=10, callbacks=[cp3])
# Out:
# Epoch 1/10
# 125/125 [==============================] - ETA: 0s - loss: 281.2291 - root_mean_squared_error: 16.7699
# WARNING:absl:Found untraced functions such as gru_cell_layer_call_fn, gru_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# 125/125 [==============================] - 18s 118ms/step - loss: 281.2291 - root_mean_squared_error: 16.7699 - val_loss: 264.4203 - val_root_mean_squared_error: 16.2610
# Epoch 2/10
# 122/125 [============================>.] - ETA: 0s - loss: 227.0378 - root_mean_squared_error: 15.0678
# WARNING:absl:Found untraced functions such as gru_cell_layer_call_fn, gru_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# 125/125 [==============================] - 12s 100ms/step - loss: 226.7217 - root_mean_squared_error: 15.0573 - val_loss: 214.4881 - val_root_mean_squared_error: 14.6454
# Epoch 3/10
# 113/125 [==========================>...] - ETA: 0s - loss: 163.7390 - root_mean_squared_error: 12.7961
# WARNING:absl:Found untraced functions such as gru_cell_layer_call_fn, gru_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# 125/125 [==============================] - 11s 91ms/step - loss: 160.4006 - root_mean_squared_error: 12.6649 - val_loss: 140.1203 - val_root_mean_squared_error: 11.8372
# Epoch 4/10
# 119/125 [===========================>..] - ETA: 0s - loss: 113.9864 - root_mean_squared_error: 10.6764
# WARNING:absl:Found untraced functions such as gru_cell_layer_call_fn, gru_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# 125/125 [==============================] - 11s 91ms/step - loss: 112.5770 - root_mean_squared_error: 10.6102 - val_loss: 108.2469 - val_root_mean_squared_error: 10.4042
# Epoch 5/10
# 123/125 [============================>.] - ETA: 0s - loss: 90.7656 - root_mean_squared_error: 9.5271
# WARNING:absl:Found untraced functions such as gru_cell_layer_call_fn, gru_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# 125/125 [==============================] - 11s 92ms/step - loss: 90.7137 - root_mean_squared_error: 9.5244 - val_loss: 90.7175 - val_root_mean_squared_error: 9.5246
# Epoch 6/10
# 117/125 [===========================>..] - ETA: 0s - loss: 78.6619 - root_mean_squared_error: 8.8692
# WARNING:absl:Found untraced functions such as gru_cell_layer_call_fn, gru_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# 125/125 [==============================] - 12s 95ms/step - loss: 77.6429 - root_mean_squared_error: 8.8115 - val_loss: 78.6238 - val_root_mean_squared_error: 8.8670
# Epoch 7/10
# 123/125 [============================>.] - ETA: 0s - loss: 68.1311 - root_mean_squared_error: 8.2542
# WARNING:absl:Found untraced functions such as gru_cell_layer_call_fn, gru_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# 125/125 [==============================] - 13s 102ms/step - loss: 68.6744 - root_mean_squared_error: 8.2870 - val_loss: 70.5856 - val_root_mean_squared_error: 8.4015
# Epoch 8/10
# 125/125 [==============================] - ETA: 0s - loss: 62.6466 - root_mean_squared_error: 7.9150
# WARNING:absl:Found untraced functions such as gru_cell_layer_call_fn, gru_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# 125/125 [==============================] - 13s 102ms/step - loss: 62.6466 - root_mean_squared_error: 7.9150 - val_loss: 65.0731 - val_root_mean_squared_error: 8.0668
# Epoch 9/10
# 122/125 [============================>.] - ETA: 0s - loss: 58.8106 - root_mean_squared_error: 7.6688
# WARNING:absl:Found untraced functions such as gru_cell_layer_call_fn, gru_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# 125/125 [==============================] - 12s 96ms/step - loss: 58.4406 - root_mean_squared_error: 7.6446 - val_loss: 60.7980 - val_root_mean_squared_error: 7.7973
# Epoch 10/10
# 111/125 [=========================>....] - ETA: 0s - loss: 54.2419 - root_mean_squared_error: 7.3649
# WARNING:absl:Found untraced functions such as gru_cell_layer_call_fn, gru_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# 125/125 [==============================] - 12s 95ms/step - loss: 54.9930 - root_mean_squared_error: 7.4157 - val_loss: 57.2446 - val_root_mean_squared_error: 7.5660

# %% [markdown]
# # Multivariate Time Series Forecasting (LSTM) for one target

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# ## Preprocessing

# %%
multi_df = pred_data.copy()
multi_df.index = pd.to_datetime(multi_df['timestamp'], format='%Y-%m-%d %H:%M:%S')
multi_df['Seconds'] = multi_df.index.map(pd.Timestamp.timestamp)
multi_df
# Out:
#                                timestamp  east inbound  north inbound  \
# timestamp
# 2020-06-01 00:00:00  2020-06-01 00:00:00         153.0          232.0
# 2020-06-01 01:00:00  2020-06-01 01:00:00          87.0          154.4
# 2020-06-01 02:00:00  2020-06-01 02:00:00          56.0           84.8
# 2020-06-01 03:00:00  2020-06-01 03:00:00          39.0           52.6
# 2020-06-01 04:00:00  2020-06-01 04:00:00          12.0           72.5
# ...                                  ...           ...            ...
# 2022-06-01 20:00:00  2022-06-01 20:00:00          90.0          901.3
# 2022-06-01 21:00:00  2022-06-01 21:00:00          75.0          767.1
# 2022-06-01 22:00:00  2022-06-01 22:00:00          62.0          567.2
# 2022-06-01 23:00:00  2022-06-01 23:00:00          24.0          324.6
# 2022-06-02 00:00:00  2022-06-02 00:00:00          15.0          146.9
#
#                      south inbound  west inbound  east outbound  \
# timestamp
# 2020-06-01 00:00:00          224.0         275.0           28.0
# 2020-06-01 01:00:00          142.0          54.0           15.0
# 2020-06-01 02:00:00           83.0          25.0           16.0
# 2020-06-01 03:00:00           43.0          15.0            3.0
# 2020-06-01 04:00:00           50.0          11.0            4.0
# ...                            ...           ...            ...
# 2022-06-01 20:00:00          904.0         589.0          393.0
# 2022-06-01 21:00:00          652.0         510.0          263.0
# 2022-06-01 22:00:00          503.0         389.0          194.0
# 2022-06-01 23:00:00          262.0         244.0          120.0
# 2022-06-02 00:00:00          129.0         138.0           67.0
#
#                      north outbound  south outbound  west outbound  \
# timestamp
# 2020-06-01 00:00:00           206.2           185.0        1346.31
# 2020-06-01 01:00:00           125.4           116.0         406.90
# 2020-06-01 02:00:00            52.0            68.0         243.41
# 2020-06-01 03:00:00            53.4            42.0         272.47
# 2020-06-01 04:00:00            38.4            33.0         413.96
# ...                             ...             ...            ...
# 2022-06-01 20:00:00           754.2           712.0        1255.15
# 2022-06-01 21:00:00           591.8           570.0        1023.02
# 2022-06-01 22:00:00           409.6           501.0         844.69
# 2022-06-01 23:00:00           283.2           251.0         509.95
# 2022-06-02 00:00:00           140.2           130.0         263.78
#
#                      Luftdruck[hPa]  Relative Luftfeuchtigkeit[%]  \
# timestamp
# 2020-06-01 00:00:00          1021.0                         72.75
# 2020-06-01 01:00:00          1022.0                         81.75
# 2020-06-01 02:00:00          1022.0                         93.05
# 2020-06-01 03:00:00          1022.0                         96.55
# 2020-06-01 04:00:00          1022.0                         98.55
# ...                             ...                           ...
# 2022-06-01 20:00:00          1014.0                         41.10
# 2022-06-01 21:00:00          1015.5                         48.25
# 2022-06-01 22:00:00          1016.0                         59.55
# 2022-06-01 23:00:00          1017.0                         78.35
# 2022-06-02 00:00:00          1017.0                         74.60
#
#                      Temperatur[°C]  Windgeschwindigkeit[m/s]  \
# timestamp
# 2020-06-01 00:00:00           13.10                      0.60
# 2020-06-01 01:00:00           10.75                      0.40
# 2020-06-01 02:00:00            9.35                      0.45
# 2020-06-01 03:00:00            8.40                      0.55
# 2020-06-01 04:00:00            7.80                      0.40
# ...                             ...                       ...
# 2022-06-01 20:00:00           17.95                      2.15
# 2022-06-01 21:00:00           15.70                      1.30
# 2022-06-01 22:00:00           13.30                      0.75
# 2022-06-01 23:00:00           11.10                      0.70
# 2022-06-02 00:00:00           11.70                      0.75
#
#                      Windrichtung[Grad]  PM10  PM2,5    NO2       Seconds
# timestamp
# 2020-06-01 00:00:00                96.0  9.25   4.75   9.70  1.590970e+09
# 2020-06-01 01:00:00               112.0  5.65   3.25  10.05  1.590973e+09
# 2020-06-01 02:00:00                76.5  5.05   3.05  11.40  1.590977e+09
# 2020-06-01 03:00:00                71.5  6.25   3.35  11.10  1.590980e+09
# 2020-06-01 04:00:00               111.5  6.00   3.35   9.65  1.590984e+09
# ...                                 ...   ...    ...    ...           ...
# 2022-06-01 20:00:00               326.0  6.90   3.20  15.80  1.654114e+09
# 2022-06-01 21:00:00               335.0  7.85   3.60  25.30  1.654117e+09
# 2022-06-01 22:00:00               198.0  8.35   4.00  32.30  1.654121e+09
# 2022-06-01 23:00:00                41.0  9.65   4.70  26.60  1.654124e+09
# 2022-06-02 00:00:00                51.0  8.30   4.10  14.05  1.654128e+09
#
# [17541 rows x 18 columns]

# %%
day = 60*60*24
year = 365.2425*day

multi_df['Day sin'] = np.sin(multi_df['Seconds'] * (2* np.pi / day))
multi_df['Day cos'] = np.cos(multi_df['Seconds'] * (2 * np.pi / day))
multi_df['Year sin'] = np.sin(multi_df['Seconds'] * (2 * np.pi / year))
multi_df['Year cos'] = np.cos(multi_df['Seconds'] * (2 * np.pi / year))
multi_df['weekday'] = multi_df.index.day_of_week
multi_df.head()
# Out:
#                                timestamp  east inbound  north inbound  \
# timestamp
# 2022-06-01 22:00:00   4.00  1.654121e+09 -5.000000e-01  0.866025  0.498177
# 2022-06-01 23:00:00   4.70  1.654124e+09 -2.588190e-01  0.965926  0.497555
# 2022-06-02 00:00:00   4.10  1.654128e+09 -1.011061e-11  1.000000  0.496933
#
#                      Year cos  weekday
# timestamp
# 2020-06-01 00:00:00 -0.863352        0
# 2020-06-01 01:00:00 -0.863714        0
# 2020-06-01 02:00:00 -0.864075        0
# 2020-06-01 03:00:00 -0.864435        0
# 2020-06-01 04:00:00 -0.864795        0
# ...                       ...      ...
# 2022-06-01 20:00:00 -0.866360        2
# 2022-06-01 21:00:00 -0.866718        2
# 2022-06-01 22:00:00 -0.867075        2
# 2022-06-01 23:00:00 -0.867432        2
# 2022-06-02 00:00:00 -0.867789        3
#
# [17541 rows x 23 columns]

# %%
#drop unwanted columns
multi_df = multi_df.drop(columns = ['timestamp', 'Seconds'])

# %%
#replace Nans with mean
multi_df = multi_df.fillna(multi_df.mean())

# %%
multi_df
# Out:
#                        NO2  east inbound  north inbound  south inbound  \
# timestamp
# 2020-06-01 00:00:00   9.70         153.0          232.0          224.0
# 2020-06-01 01:00:00  10.05          87.0          154.4          142.0
# 2020-06-01 02:00:00  11.40          56.0           84.8           83.0
# 2020-06-01 03:00:00  11.10          39.0           52.6           43.0
# 2020-06-01 04:00:00   9.65          12.0           72.5           50.0
# ...                    ...           ...            ...            ...
# 2022-06-01 20:00:00  15.80          90.0          901.3          904.0
# 2022-06-01 21:00:00  25.30          75.0          767.1          652.0
# 2022-06-01 22:00:00  32.30          62.0          567.2          503.0
# 2022-06-01 23:00:00  26.60          24.0          324.6          262.0
# 2022-06-02 00:00:00  14.05          15.0          146.9          129.0
#
#                      west inbound  east outbound  north outbound  \
# timestamp
# 2020-06-01 00:00:00         275.0           28.0           206.2
# 2020-06-01 01:00:00          54.0           15.0           125.4
# 2020-06-01 02:00:00          25.0           16.0            52.0
# 2020-06-01 03:00:00          15.0            3.0            53.4
# 2020-06-01 04:00:00          11.0            4.0            38.4
# ...                           ...            ...             ...
# 2022-06-01 20:00:00         589.0          393.0           754.2
# 2022-06-01 21:00:00         510.0          263.0           591.8
# 2022-06-01 22:00:00         389.0          194.0           409.6
# 2022-06-01 23:00:00         244.0          120.0           283.2
# 2022-06-02 00:00:00         138.0           67.0           140.2
#
#                      south outbound  west outbound  Luftdruck[hPa]  ...  \
# timestamp                                                           ...
# 2020-06-01 00:00:00           185.0        1346.31          1021.0  ...
# 2020-06-01 01:00:00           116.0         406.90          1022.0  ...
# 2020-06-01 02:00:00            68.0         243.41          1022.0  ...
# 2020-06-01 03:00:00            42.0         272.47          1022.0  ...
# 2020-06-01 04:00:00            33.0         413.96          1022.0  ...
# ...                             ...            ...             ...  ...
# 2022-06-01 20:00:00           712.0        1255.15          1014.0  ...
# 2022-06-01 21:00:00           570.0        1023.02          1015.5  ...
# 2022-06-01 22:00:00           501.0         844.69          1016.0  ...
# 2022-06-01 23:00:00           251.0         509.95          1017.0  ...
# 75%       604.000000     1069.800000     1047.000000    1826.090000
# max      1673.000000     1708.200000     2750.000000    4063.250000
#
#        Luftdruck[hPa]  Relative Luftfeuchtigkeit[%]  ...  \
# count    17541.000000                  17541.000000  ...
# mean      1017.280325                     77.321671  ...
# std          8.921590                     20.474889  ...
# min        980.000000                     24.250000  ...
# 25%       1012.500000                     61.900000  ...
# 50%       1018.000000                     83.050000  ...
# 75%       1023.000000                     95.600000  ...
# max       1041.000000                    100.100000  ...
#
#        Windgeschwindigkeit[m/s]  Windrichtung[Grad]          PM10  \
# count              17541.000000        17541.000000  17541.000000
# mean                   1.211699          149.424409     14.228799
# std                    0.611074           87.290741     10.375028
# min                    0.350000            1.000000      0.500000
# 25%                    0.750000           66.000000      8.250000
# 50%                    1.100000          154.000000     12.350000
# 75%                    1.550000          229.000000     17.650000
# max                    5.400000          360.000000    399.500000
#
#               PM2,5           NO2       Day sin       Day cos      Year sin  \
# count  17541.000000  17541.000000  1.754100e+04  1.754100e+04  17541.000000
# mean       9.215885     27.321615 -2.749911e-05 -1.518672e-04      0.000366
# std        6.079822     15.164261  7.071618e-01  7.070920e-01      0.706934
# min        0.500000      2.150000 -1.000000e+00 -1.000000e+00     -1.000000
# 25%        4.700000     16.200000 -7.071068e-01 -7.071068e-01     -0.706555
# 50%        7.700000     24.650000 -1.801471e-14  1.552518e-14      0.001240
# 75%       12.200000     35.250000  7.071068e-01  7.071068e-01      0.706510
# max       62.650000    156.950000  1.000000e+00  1.000000e+00      1.000000
#
#            Year cos       weekday
# count  17541.000000  17541.000000
# mean      -0.000728      2.991107
# std        0.707320      2.000379
# min       -1.000000      0.000000
# 25%       -0.708442      1.000000
# 50%       -0.001566      3.000000
# 75%        0.706786      5.000000
# max        1.000000      6.000000
#
# [8 rows x 21 columns]

# %%
#standardize

scaler = MinMaxScaler(feature_range=(-1, 1))

multi_df_scaled = scaler.fit_transform(multi_df)
multi_df_scaled = pd.DataFrame(multi_df_scaled, columns=multi_df.columns, index=multi_df.index)

# %%
multi_df_sc = multi_df.copy()

scaler_X = MinMaxScaler(feature_range=(0, 1))
scaler_y = MinMaxScaler(feature_range=(0, 1))

# Separate your DataFrame into features and target variable
X = multi_df_sc.drop(columns=["NO2"])

y = multi_df_sc[[ "NO2"]]

# Scale the features (X) and target (y) separately
X_scaled = scaler_X.fit_transform(X)
y_scaled = scaler_y.fit_transform(y).flatten()

# Create a new DataFrame with the scaled features and target variable
X_scaled_df = pd.DataFrame(data=X_scaled, columns=X.columns, index=multi_df_sc.index)
y_scaled_df  = pd.DataFrame(data=y_scaled, columns=y.columns, index=multi_df_sc.index)
#df_scaled = y_scaled_df.merge(X_scaled_df, left_index=True, right_index=True)
#df_scaled
X_scaled_df
# Out:
#                      east inbound  north inbound  south inbound  west inbound  \
# timestamp
# 2020-06-01 00:00:00      0.075855       0.106295       0.073346      0.207078
# 2020-06-01 01:00:00      0.043133       0.070741       0.046496      0.040663
# 2020-06-01 02:00:00      0.027764       0.038853       0.027177      0.018825
# 2020-06-01 03:00:00      0.019336       0.024100       0.014080      0.011295
# 2020-06-01 04:00:00      0.005949       0.033217       0.016372      0.008283
# ...                           ...            ...            ...           ...
# 2022-06-01 20:00:00      0.044621       0.412948       0.296005      0.443524
# 2020-06-01 00:00:00  0.068383  0.500000  1.000000  0.752301  0.068324
# 2020-06-01 01:00:00  0.044248  0.629410  0.982963  0.751992  0.068143
# 2020-06-01 02:00:00  0.041030  0.750000  0.933013  0.751682  0.067963
# 2020-06-01 03:00:00  0.045857  0.853553  0.853553  0.751372  0.067782
# 2020-06-01 04:00:00  0.045857  0.933013  0.750000  0.751062  0.067602
# ...                       ...       ...       ...       ...       ...
# 2022-06-01 20:00:00  0.043443  0.066987  0.750000  0.749710  0.066820
# 2022-06-01 21:00:00  0.049879  0.146447  0.853553  0.749399  0.066641
# 2022-06-01 22:00:00  0.056315  0.250000  0.933013  0.749088  0.066462
# 2022-06-01 23:00:00  0.067578  0.370590  0.982963  0.748778  0.066284
# 2022-06-02 00:00:00  0.057924  0.500000  1.000000  0.748467  0.066106
#
#                       weekday
# timestamp
# 2020-06-01 00:00:00  0.000000
# 2020-06-01 01:00:00  0.000000
# 2020-06-01 02:00:00  0.000000
# 2020-06-01 03:00:00  0.000000
# 2020-06-01 04:00:00  0.000000
# ...                       ...
# 2022-06-01 20:00:00  0.333333
# 2022-06-01 21:00:00  0.333333
# 2022-06-01 22:00:00  0.333333
# 2022-06-01 23:00:00  0.333333
# 2022-06-02 00:00:00  0.500000
#
# [17541 rows x 20 columns]

# %% [markdown]
# ## Create tensors

# %%
#create X and Y
def df_to_X_y2(df, window_size=10):
  df_as_np = df.to_numpy()
  X = []
  y = []
  for i in range(len(df_as_np)-window_size):
    row = [r for r in df_as_np[i:i+window_size]]
    X.append(row)
    #define y
    label = y_scaled[(i +window_size )]
    y.append(label)
  return np.array(X), np.array(y)

# %%
X2, y2 = df_to_X_y2(X_scaled_df)
X2.shape, y2.shape
# Out:
# ((17531, 10, 20), (17531,))

# %%
#split data
X2_train, y2_train = X2[:10000], y2[:10000]
X2_val, y2_val = X2[10000:13500], y2[10000:13500]
X2_test, y2_test = X2[13500:], y2[13500:]
X2_train.shape, y2_train.shape, X2_val.shape, y2_val.shape, X2_test.shape, y2_test.shape
# Out:
# ((10000, 10, 20), (10000,), (3500, 10, 20), (3500,), (4031, 10, 20), (4031,))

# %% [markdown]
# # Create model & predict

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adagrad
from tensorflow.keras.regularizers import l1
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.metrics import MeanAbsoluteError, RootMeanSquaredError
from tensorflow.keras.backend import clear_session
from tensorflow.keras.models import load_model
from keras.preprocessing.sequence import TimeseriesGenerator


from sklearn.metrics import mean_squared_error as mse

# %%
#create SMALL model

clear_session()

model4 = Sequential()
model4.add(InputLayer((10, 21)))
model4.add(LSTM(64))
model4.add(Dense(8, 'relu'))
model4.add(Dense(1, 'linear'))

model4.summary()

# %%
# Clear the Keras session
clear_session()

# Set up checkpoint to save the best model
cp4 = ModelCheckpoint('model8/', save_best_only=True)

# Create the model
model4 = Sequential()

# Input layer
model4.add(InputLayer((10,20)))

model4.add(LSTM(512))
model4.add(Dropout(0.2))

# Decrease the number of neurons in Dense layers and add L1-Regularization
model4.add(Dense(164, activation='linear'))#, kernel_regularizer=l1(0.001)))
model4.add(Dense(24, activation='linear'))#, kernel_regularizer=l1(0.001)))

model4.add(Dense(1, activation='linear'))

#model4.compile(loss='mean_absolute_error', optimizer=Adagrad(learning_rate=1), metrics=[RootMeanSquaredError()])
model4.compile(loss='mean_absolute_error', optimizer=Adam(learning_rate=0.001), metrics=['mean_squared_error'])

# Display model summary
model4.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 512)               1091584
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense (Dense)               (None, 164)               84132
#
#  dense_1 (Dense)             (None, 24)                3960
#
#  dense_2 (Dense)             (None, 1)                 25
#
# =================================================================
# Total params: 1,179,701
# Trainable params: 1,179,701
# Non-trainable params: 0
# _________________________________________________________________

# %%
#fit model
model4.fit(X2_train, y2_train, validation_data=(X2_val, y2_val), epochs
130
# 313/313 [==============================] - 16s 50ms/step - loss: 0.0156 - mean_squared_error: 5.3518e-04 - val_loss: 0.0496 - val_mean_squared_error: 0.0046
# Epoch 124/130
# 313/313 [==============================] - 16s 51ms/step - loss: 0.0152 - mean_squared_error: 4.9279e-04 - val_loss: 0.0487 - val_mean_squared_error: 0.0045
# Epoch 125/130
# 313/313 [==============================] - 16s 51ms/step - loss: 0.0152 - mean_squared_error: 5.0359e-04 - val_loss: 0.0493 - val_mean_squared_error: 0.0047
# Epoch 126/130
# 313/313 [==============================] - 16s 50ms/step - loss: 0.0155 - mean_squared_error: 5.1018e-04 - val_loss: 0.0502 - val_mean_squared_error: 0.0047
# Epoch 127/130
# 313/313 [==============================] - 16s 51ms/step - loss: 0.0151 - mean_squared_error: 4.9063e-04 - val_loss: 0.0494 - val_mean_squared_error: 0.0046
# Epoch 128/130
# 313/313 [==============================] - 16s 51ms/step - loss: 0.0150 - mean_squared_error: 4.8468e-04 - val_loss: 0.0496 - val_mean_squared_error: 0.0046
# Epoch 129/130
# 313/313 [==============================] - 16s 50ms/step - loss: 0.0147 - mean_squared_error: 4.5507e-04 - val_loss: 0.0505 - val_mean_squared_error: 0.0049
# Epoch 130/130
# 313/313 [==============================] - 16s 50ms/step - loss: 0.0146 - mean_squared_error: 4.5142e-04 - val_loss: 0.0480 - val_mean_squared_error: 0.0044

# %%
# function to predict and plot predictions
def plot_predictions1(model, X, y, start=0, end=100):
  predictions = model.predict(X).flatten()
  df = pd.DataFrame(data={'Predictions':predictions, 'Actuals':y})
  plt.plot(df['Predictions'][start:end], label = 'Predictions')
  plt.plot(df['Actuals'][start:end], label = 'Actuals')
  plt.legend()
  return df, mse(y, predictions)

# %%
predictions = model4.predict(X2_test).flatten()
len(predictions)
# Out:
# 127/127 [==============================] - 1s 11ms/step
# 4034

# %%
len(y2_test)
# Out:
# 4034

# %%
plot_predictions1(model4, X2_test, y2_test)
# Out:
# 126/126 [==============================] - 2s 12ms/step
# (      Predictions   Actuals
#  0        0.148673  0.145349
#  1        0.133531  0.134690
#  2        0.117745  0.150194
#  3        0.114823  0.155039
#  4        0.119823  0.169251
#  ...           ...       ...
#  4026     0.171523  0.088178
#  4027     0.175043  0.149548
#  4028     0.144636  0.194767
#  4029     0.097207  0.157946
#  4030     0.080299  0.076873
#
#  [4031 rows x 2 columns],
#  0.004807239857740504)

# %% [markdown]
# ## Predict multiple targets

# %%
multi_df2 = multi_df

# %%
multi_df2.describe()
# Out:
#        east inbound  north inbound  south inbound  west inbound  \
# count  17541.000000   17541.000000   17541.000000  17541.000000
# mean     637.070520     801.798704     838.763448    453.455789
# std      489.928779     555.434910     600.370981    303.501293
# min       -0.000000      -0.000000      -0.000000     -0.000000
# 25%      145.000000     213.600000     200.000000    143.000000
# 50%      563.000000     803.800000     867.000000    467.000000
# 75%     1098.000000    1327.600000    1384.000000    737.000000
# max     2017.000000    2182.600000    3054.000000   1328.000000
#
#        east outbound  north outbound  south outbound  west outbound  \
# count   17541.000000    17541.000000    17541.000000   17541.000000
# mean      365.108204      605.522388      671.412006    1148.101487
# std       313.133069      460.708475      511.746900     859.736520
# min         0.000000        0.000000        0.000000       0.000000
# 25%        69.000000      153.000000      172.000000     285.760000
# 50%       295.000000      508.400000      624.000000    1093.240000
# 75%       604.000000     1069.800000     1047.000000    1826.090000
# max      1673.000000     1708.200000     2750.000000    4063.250000
#
#        Luftdruck[hPa]  Relative Luftfeuchtigkeit[%]  ...  \
# count    17541.000000                  17541.000000  ...
# mean      1017.280325                     77.321671  ...
# std          8.921590                     20.474889  ...
# min        980.000000                     24.250000  ...
# 25%       1012.500000                     61.900000  ...
# 50%       1018.000000                     83.050000  ...
# 75%       1023.000000                     95.600000  ...
# max       1041.000000                    100.100000  ...
#
#        Windgeschwindigkeit[m/s]  Windrichtung[Grad]          PM10  \
# count              17541.000000        17541.000000  17541.000000
# mean                   1.211699          149.424409     14.228799
# std                    0.611074           87.290741     10.375028
# min                    0.350000            1.000000      0.500000
# 25%                    0.750000           66.000000      8.250000
# 50%                    1.100000          154.000000     12.350000
# 75%                    1.550000          229.000000     17.650000
# max                    5.400000          360.000000    399.500000
#
#               PM2,5           NO2       Day sin       Day cos      Year sin  \
# count  17541.000000  17541.000000  1.754100e+04  1.754100e+04  17541.000000
# mean       9.215885     27.321615 -2.749911e-05 -1.518672e-04      0.000366
# std        6.079822     15.164261  7.071618e-01  7.070920e-01      0.706934
# min        0.500000      2.150000 -1.000000e+00 -1.000000e+00     -1.000000
# 25%        4.700000     16.200000 -7.071068e-01 -7.071068e-01     -0.706555
# 50%        7.700000     24.650000 -1.801471e-14  1.552518e-14      0.001240
# 75%       12.200000     35.250000  7.071068e-01  7.071068e-01      0.706510
# max       62.650000    156.950000  1.000000e+00  1.000000e+00      1.000000
#
#            Year cos       weekday
# count  17541.000000  17541.000000
# mean      -0.000728      2.991107
# std        0.707320      2.000379
# min       -1.000000      0.000000
# 25%       -0.708442      1.000000
# 50%       -0.001566      3.000000
# 75%        0.706786      5.000000
# max        1.000000      6.000000
#
# [8 rows x 21 columns]

# %%
scaler_X = MinMaxScaler(feature_range=(0, 1))
scaler_y = MinMaxScaler(feature_range=(0, 1))

# Separate your DataFrame into features and target variable
X = multi_df2.drop(columns=["PM10", "PM2,5", "NO2"])

y = multi_df2[["PM10", "PM2,5", "NO2"]]

# Scale the features (X) and target (y) separately
X_scaled = scaler_X.fit_transform(X)
y_scaled = scaler_y.fit_transform(y)

# Create a new DataFrame with the scaled features and target variable
X_scaled_df = pd.DataFrame(data=X_scaled, columns=X.columns, index=multi_df2.index)
y_scaled_df  = pd.DataFrame(data=y_scaled, columns=y.columns, index=multi_df2.index)
#df_scaled = y_scaled_df.merge(X_scaled_df, left_index=True, right_index=True)
#df_scaled
X_scaled_df
# Out:
#                      east inbound  north inbound  south inbound  west inbound  \
# timestamp
# 2020-06-01 00:00:00      0.075855       0.106295       0.073346      0.207078
# 2020-06-01 01:00:00      0.043133       0.070741       0.046496      0.040663
# 2020-06-01 02:00:00      0.027764       0.038853       0.027177      0.018825
# 2020-06-01 03:00:00      0.019336       0.024100       0.014080      0.011295
# 2020-06-01 04:00:00      0.005949       0.033217       0.016372      0.008283
# ...                           ...            ...            ...           ...
# 2022-06-01 20:00:00      0.044621       0.412948       0.296005      0.443524
# 2022-06-01 21:00:00      0.037184       0.351462       0.213491      0.384036
# 2022-06-01 22:00:00      0.030739       0.259874       0.164702      0.292922
# 2022-06-01 23:00:00      0.011899       0.148722       0.085789      0.183735
# 2022-06-02 00:00:00      0.007437       0.067305       0.042240      0.103916
#
#                      east outbound  north outbound  south outbound  \
# timestamp
# 2020-06-01 00:00:00       0.016736        0.120712        0.067273
# 2020-06-01 01:00:00       0.008966        0.073411        0.042182
# 2020-06-01 02:00:00       0.009564        0.030441        0.024727
# 2020-06-01 03:00:00       0.001793        0.031261        0.015273
191214], [0.031454, 0.131134, 0.151486], [0.03183, 0.127112, 0.151163], [0.031078, 0.139179, 0.101744], [0.042356, 0.169751, 0.104974], [0.042481, 0.19469, 0.109496], [0.048371, 0.230088, 0.135336], [0.049624, 0.242156, 0.150517], [0.047118, 0.220434, 0.149871], [0.053509, 0.246179, 0.215762], [0.062406, 0.253419, 0.324289], [0.080952, 0.275945, 0.435724], [0.058521, 0.25181, 0.578165], [0.053759, 0.249397, 0.207041], [0.063659, 0.281577, 0.248708], [0.039474, 0.174578, 0.32655], [0.017168, 0.079646, 0.208333], [0.024185, 0.099759, 0.220284], [0.031704, 0.139179, 0.271964], [0.052632, 0.266291, 0.343669], [0.056767, 0.303298, 0.243217], [0.057769, 0.306516, 0.207364], [0.047243, 0.243765, 0.16699], [0.037719, 0.179405, 0.216731], [0.042982, 0.191472, 0.14761], [0.044236, 0.209976, 0.122093], [0.03797, 0.179405, 0.086886], [0.015288, 0.060338, 0.054587], [0.021679, 0.088496, 0.055233], [0.023308, 0.095736, 0.055879], [0.020426, 0.086887, 0.044897], [0.019549, 0.074819, 0.059109], [0.022431, 0.081255, 0.129522], [0.020426, 0.071601, 0.159561], [0.065038, 0.242961, 0.208333], [0.040977, 0.174578, 0.13469], [0.023308, 0.077233, 0.170543], [0.03396, 0.077233, 0.092377], [0.033584, 0.086887, 0.124031], [0.030827, 0.08206, 0.088824], [0.028321, 0.080451, 0.08301], [0.024436, 0.074014, 0.097222], [0.022556, 0.071601, 0.092054], [0.018045, 0.052293, 0.08624], [0.020426, 0.066774, 0.156008], [0.010401, 0.035398, 0.080426], [0.010526, 0.037007, 0.060724], [0.013659, 0.051488, 0.051034], [0.014536, 0.054706, 0.076227], [0.014286, 0.053097, 0.039729], [0.011153, 0.034594, 0.040698], [0.011153, 0.036203, 0.049742], [0.014787, 0.042639, 0.0323], [0.014536, 0.051488, 0.061693], [0.022807, 0.085278, 0.053295], [0.018546, 0.076428, 0.04199], [0.01792, 0.070796, 0 ...

# %%
#create windows
def df_to_X_y2(df, window_size=10):
  df_as_np = df.to_numpy()
  X = []
  y = []
  for i in range(len(df_as_np)-window_size):
    n_steps_out = 3
    row = [r for r in df_as_np[i:i+window_size]]
    X.append(row)
    #define y
      #if y is still in X
    #label = [df_as_np[i+window_size][0], df_as_np[i+window_size][1], df_as_np[i+window_size][2]]
      #multistep multivariate forecasting
    label = y_scaled[(i +window_size ):(i +window_size + n_steps_out)]
    
    y.append(label)
  return np.array(X), np.array(y)

# %%
import numpy as np

def df_to_X_y_multistep(df, window_size=10, n_steps_ahead=3):
    df_as_np = df.to_numpy()
    X = []
    y = []

    for i in range(len(df_as_np) - window_size - n_steps_ahead + 1):
        # Create the input sequence (X)
        input_sequence = [df_as_np[i:i + window_size]]

        # Define y for multistep forecasting
        label = [df_as_np[i + window_size:i + window_size + n_steps_ahead]]

        X.append(input_sequence)
        y.append(label)

    return np.array(X), np.array(y)

# %%
X12, y12 = df_to_X_y_multistep(X_scaled_df)
X12.shape, y12.shape
# Out:
# ((17529, 1, 10, 18), (17529, 1, 3, 18))

# %%
# Split data
X12_train, y12_train = X12[:10000], y12[:10000]
X12_val, y12_val = X12[10000:13500], y12[10000:13500]
X12_test, y12_test = X12[13500:], y12[13500:]
X12_train.shape, y12_train.shape, X12_val.shape, y12_val.shape, X12_test.shape, y12_test.shape
# Out:
# ((10000, 1, 10, 18),
#  (10000, 1, 3, 18),
#  (3500, 1, 10, 18),
#  (3500, 1, 3, 18),
#  (4029, 1, 10, 18),
#  (4029, 1, 3, 18))

# %%
X5, y5 = df_to_X_y2(X_scaled_df)
X5.shape, y5.shape
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\Data Science\VS Code\final_project\code_repository\time_series_prediction_2020-2022_3rd_iteration.ipynb Cell 68 line <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/Data%20Science/VS%20Code/final_project/code_repository/time_series_prediction_2020-2022_3rd_iteration.ipynb#Y122sZmlsZQ%3D%3D?line=0'>1</a> X5, y5 = df_to_X_y2(X_scaled_df)
#       <a href='vscode-notebook-cell:/d%3A/Data%20Science/VS%20Code/final_project/code_repository/time_series_prediction_2020-2022_3rd_iteration.ipynb#Y122sZmlsZQ%3D%3D?line=1'>2</a> X5.shape, y5.shape
#
# d:\Data Science\VS Code\final_project\code_repository\time_series_prediction_2020-2022_3rd_iteration.ipynb Cell 68 line df_to_X_y2(df, window_size)
#      <a href='vscode-notebook-cell:/d%3A/Data%20Science/VS%20Code/final_project/code_repository/time_series_prediction_2020-2022_3rd_iteration.ipynb#Y122sZmlsZQ%3D%3D?line=13'>14</a>   label = y_scaled[(i +window_size ):(i +window_size + n_steps_out)]
#      <a href='vscode-notebook-cell:/d%3A/Data%20Science/VS%20Code/final_project/code_repository/time_series_prediction_2020-2022_3rd_iteration.ipynb#Y122sZmlsZQ%3D%3D?line=15'>16</a>   y.append(label)
# ---> <a href='vscode-notebook-cell:/d%3A/Data%20Science/VS%20Code/final_project/code_repository/time_series_prediction_2020-2022_3rd_iteration.ipynb#Y122sZmlsZQ%3D%3D?line=16'>17</a> return np.array(X), np.array(y)
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (17531,) + inhomogeneous part.

# %%
#split data
X5_train, y5_train = X5[:10000], y5[:10000]
X5_val, y5_val = X5[10000:13500], y5[10000:13500]
X5_test, y5_test = X5[13500:], y5[13500:]
X5_train.shape, y5_train.shape, X5_val.shape, y5_val.shape, X5_test.shape, y5_test.shape
# Out:
# ((10000, 10, 18),
#  (10000, 3),
#  (3500, 10, 18),
#  (3500, 3),
#  (4031, 10, 18),
#  (4031, 3))

# %% [markdown]
# ### Create model

# %%
#create model

# Clear the Keras session
clear_session()

# Set up checkpoint to save the best model
cp5 = ModelCheckpoint('model8/', save_best_only=True)

# Create the model
model5 = Sequential()

# Input layer
model5.add(InputLayer((10,18)))

model5.add(LSTM(512))
model5.add(Dropout(0.2))

# Decrease the number of neurons in Dense layers and add L1-Regularization
model5.add(Dense(164, activation='linear'))#, kernel_regularizer=l1(0.001)))
model5.add(Dense(24, activation='linear'))#, kernel_regularizer=l1(0.001)))


model5.add(Dense(3, activation='linear'))

#model5.compile(loss='mean_absolute_error', optimizer=Adagrad(learning_rate=1), metrics=[RootMeanSquaredError()])
model5.compile(loss='mean_absolute_error', optimizer=Adam(learning_rate=0.001), metrics=['mean_squared_error'])

# Display model summary
model5.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 512)               1087488
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense (Dense)               (None, 164)               84132
#
#  dense_1 (Dense)             (None, 24)                3960
#
#  dense_2 (Dense)             (None, 3)                 75
#
# =================================================================
# Total params: 1,175,655
# Trainable params: 1,175,655
# Non-trainable params: 0
# _________________________________________________________________

# %%
model5.fit(X5_train, y5_train, validation_data=(X5_val, y5_val), epochs=5, callbacks=[cp5])
# Out:
# Epoch 1/5
# 312/313 [============================>.] - ETA: 0s - loss: 0.0593 - mean_squared_error: 0.0115
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# 313/313 [==============================] - 33s 94ms/step - loss: 0.0592 - mean_squared_error: 0.0114 - val_loss: 0.0468 - val_mean_squared_error: 0.0051
# Epoch 2/5
# 313/313 [==============================] - ETA: 0s - loss: 0.0452 - mean_squared_error: 0.0051
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# 313/313 [==============================] - 28s 89ms/step - loss: 0.0452 - mean_squared_error: 0.0051 - val_loss: 0.0431 - val_mean_squared_error: 0.0042
# Epoch 3/5
# 313/313 [==============================] - ETA: 0s - loss: 0.0430 - mean_squared_error: 0.0047
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# 313/313 [==============================] - 29s 92ms/step - loss: 0.0430 - mean_squared_error: 0.0047 - val_loss: 0.0401 - val_mean_squared_error: 0.0040
# Epoch 4/5
# 313/313 [==============================] - 16s 50ms/step - loss: 0.0417 - mean_squared_error: 0.0045 - val_loss: 0.0487 - val_mean_squared_error: 0.0052
# Epoch 5/5
# 312/313 [============================>.] - ETA: 0s - loss: 0.0408 - mean_squared_error: 0.0043
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# 313/313 [==============================] - 31s 98ms/step - loss: 0.0408 - mean_squared_error: 0.0043 - val_loss: 0.0363 - val_mean_squared_error: 0.0032

# %%
#fit model
model5.fit(X12_train, y12_train, validation_data=(X12_val, y12_val), epochs=5, callbacks=[cp5])
# Out:
# Epoch 1/5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\Data Science\VS Code\final_project\code_repository\time_series_prediction_2020-2022_3rd_iteration.ipynb Cell 71 line <cell line: 2>()
#       <a href='vscode-notebook-cell:/d%3A/Data%20Science/VS%20Code/final_project/code_repository/time_series_prediction_2020-2022_3rd_iteration.ipynb#Y126sZmlsZQ%3D%3D?line=0'>1</a> #fit model
# ----> <a href='vscode-notebook-cell:/d%3A/Data%20Science/VS%20Code/final_project/code_repository/time_series_prediction_2020-2022_3rd_iteration.ipynb#Y126sZmlsZQ%3D%3D?line=1'>2</a> model5.fit(X12_train, y12_train, validation_data=(X12_val, y12_val), epochs=5, callbacks=[cp5])
#
# File c:\Users\cathr\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\AppData\Local\Temp\__autograph_generated_file6wbkwar9.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__train_function(iterator)
#      13 try:
#      14     do_return = True
# ---> 15     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16 except:
#      17     do_return = False
#
# ValueError: in user code:
#
#     File "c:\Users\cathr\anaconda3\lib\site-packages\keras\engine\training.py", line 1160, in train_function  *
#         return step_function(self, iterator)
#     File "c:\Users\cathr\anaconda3\lib\site-packages\keras\engine\training.py", line 1146, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "c:\Users\cathr\anaconda3\lib\site-packages\keras\engine\training.py", line 1135, in run_step  **
#         outputs = model.train_step(data)
#     File "c:\Users\cathr\anaconda3\lib\site-packages\keras\engine\training.py", line 993, in train_step
#         y_pred = self(x, training=True)
#     File "c:\Users\cathr\anaconda3\lib\site-packages\keras\utils\traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "c:\Users\cathr\anaconda3\lib\site-packages\keras\engine\input_spec.py", line 295, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 0 of layer "sequential" is incompatible with the layer: expected shape=(None, 10, 18), found shape=(None, 1, 10, 18)

# %%
#load model
#model5 = load_model('model5/')
#model6 = load_model('model7/')
model6 = load_model('model8/')

# %%
# prdiction for one target value

def plot_predictions5(model, X, y, start=0, end=400):
  predictions = model.predict(X).flatten()
  df = pd.DataFrame(data={'Predictions':predictions, 'Actuals':y})
  plt.plot(df['Predictions'][start:end])
  plt.plot(df['Actuals'][start:end])
  return df, mse(y, predictions)

# %%
#prediction for multiple target values

def plot_predictions2(model, X, y, start=0, end=100):
  predictions = model.predict(X)
  pm10_preds, pm25_preds, no2_preds = predictions[:, 0], predictions[:, 1], predictions[:, 2]
  pm10_actuals, pm25_actuals, no2_actuals = y[:, 0], y[:, 1], y[:, 2]
  df_pred = pd.DataFrame(data={'PM 10 Predictions': pm10_preds,
                          'PM 10 Actuals':pm10_actuals,
                          'PM 2,5 Predictions': pm25_preds,
                          'PM 2,5 Actuals': pm25_actuals,
                          'NO2 Predictions': no2_preds,
                          'NO2 Actuals': no2_actuals
                          })
  fig, axes = plt.subplots(2,2, figsize=(12, 8))

  # Plot PM10 Predictions and Actuals
  axes[0, 0].plot(df_pred['PM 10 Predictions'][start:end], label='PM10 Predictions')
  axes[0, 0].plot(df_pred['PM 10 Actuals'][start:end], label='PM10 Actuals')
  axes[0, 0].legend()

  # Plot PM2.5 Predictions and Actuals
  axes[0, 1].plot(df_pred['PM 2,5 Predictions'][start:end], label='PM2.5 Predictions')
  axes[0, 1].plot(df_pred['PM 2,5 Actuals'][start:end], label='PM2.5 Actuals')
  axes[0, 1].legend()

  # Plot NO2 Predictions and Actuals
  axes[1, 0].plot(df_pred['NO2 Predictions'][start:end], label='NO2 Predictions')
  axes[1, 0].plot(df_pred['NO2 Actuals'][start:end], label='NO2 Actuals')
  axes[1, 0].legend()

  # Remove the empty subplot
  fig.delaxes(axes[1, 1])

  plt.tight_layout()
  
  plt.savefig('plot_predictions.png')
  plt.show()
  return show(df_pred[start:end])

# %%
model6.evaluate(X5_test, y5_test)
# Out:
# 126/126 [==============================] - 2s 12ms/step - loss: 0.0452 - mean_squared_error: 0.0047
# [0.045241400599479675, 0.004672893323004246]

# %%
plot_predictions2(model6, X5_test, y5_test)
# Out:
# 126/126 [==============================] - 2s 13ms/step
# <style>.itables table td {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables table th {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables thead input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
#
# .itables tfoot input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
# </style>
# <div class="itables">
# <table id
 0.252467, 0.270995], [0.039997, 0.044862, 0.165269, 0.186645, 0.258703, 0.226098], [0.038067, 0.030702, 0.157025, 0.133548, 0.25777, 0.205103], [0.036306, 0.036967, 0.150419, 0.115044, 0.258245, 0.258075], [0.035688, 0.043609, 0.149615, 0.139179, 0.275299, 0.349483], [0.035722, 0.041479, 0.151305, 0.167337, 0.293637, 0.361434], [0.035784, 0.042105, 0.154237, 0.184232, 0.289237, 0.310401], [0.036266, 0.042982, 0.159909, 0.209976, 0.278745, 0.30491], [0.036337, 0.049123, 0.164298, 0.241352, 0.257429, 0.315891], [0.03656, 0.037218, 0.169535, 0.161706, 0.240245, 0.231912], [0.037064, 0.037093, 0.174245, 0.166533, 0.230695, 0.193152], [0.037412, 0.03183, 0.176551, 0.176991, 0.215438, 0.144703], [0.038059, 0.035338, 0.179102, 0.19469, 0.201594, 0.162791], [0.03874, 0.038722, 0.182781, 0.216412, 0.192622, 0.165698], [0.039403, 0.036591, 0.1837, 0.213194, 0.187552, 0.196059], [0.039994, 0.026817, 0.184379, 0.164119, 0.180391, 0.180879], [0.040873, 0.031454, 0.187159, 0.193886, 0.179412, 0.140827], [0.041048, 0.023183, 0.187488, 0.139179, 0.170581, 0.146964], [0.04131, 0.025564, 0.189502, 0.151247, 0.16644, 0.142442], [0.041087, 0.02782, 0.190743, 0.16251, 0.1578, 0.135982], [0.041739, 0.03183, 0.194732, 0.172164, 0.170236, 0.161499], [0.042629, 0.037093, 0.198038, 0.181818, 0.194872, 0.171512], [0.043206, 0.037719, 0.199503, 0.193886, 0.212278, 0.157623], [0.042212, 0.038221, 0.195414, 0.197908, 0.214999, 0.156654], [0.040427, 0.03396, 0.188948, 0.184232, 0.209517, 0.130814], [0.038434, 0.029198, 0.181812, 0.15527, 0.207678, 0.218023], [0.0364, 0.029574, 0.17332, 0.147224, 0.212307, 0.209625], [0.035438, 0.030952, 0.170115, 0.160097, 0.227959, 0.226421], [0.034469, 0.028697, 0.167774, 0.152051, 0.228158, 0.203811], [0. ...
#
#     // Define the dt_args
#     let dt_args = {"order": []};
#     dt_args["data"] = data;
#
#     $(document).ready(function () {
#
#         $('#0c58d2de-2d46-4bf3-95fd-c29f1e231670').DataTable(dt_args);
#     });
# </script>
# </div>

# %% [markdown]
# ### Invert Prediction Values
# Not working for multitarget predictions

# %%
# Reshape 'Predictions' and 'Actuals' to have one feature
predictions = df['Predictions'].values.reshape(-1, 1)
actuals = df['Actuals'].values.reshape(-1, 1)

# %%
predictions_inverted = scaler_y.inverse_transform(predictions)
actuals_inverted = scaler_y.inverse_transform(actuals)

# %%
df_inverted = pd.DataFrame({
    'Predictions': predictions_inverted.flatten(),
    'Actuals': actuals_inverted.flatten()
})
df_inverted
# Out:
#     Predictions  Actuals
# 0     17.151331     11.6
# 1     16.885956     11.0
# 2     15.532189      6.2
# 3     13.222870      7.8
# 4     13.280419      6.9
# 5     11.861265      8.1
# 6     12.661733      8.6
# 7     13.150102      8.4
# 8     12.224852      6.6
# 9     11.035548      8.0
# 10    10.985045      8.5
# 11    10.452996      8.1
# 12     9.299650     13.0
# 13    10.615696     12.9
# 14    11.208577     11.7
# 15    10.617084      6.5
# 16     7.441206      9.5
# 17     9.347011      7.4
# 18     9.162146      5.7
# 19     7.671333     15.4
# 20    13.916196     14.9
# 21    14.518785     18.3
# 22    15.579004     15.4
# 23    14.276018     14.7
# 24    13.616910     18.7
# 25    14.605068      8.1
# 26    10.335052      9.1
# 27    11.128181     12.9
# 28    12.670075     21.3
# 29    17.721695     20.7
# 30    17.761660     20.5
# 31    16.682827     22.0
# 32    17.854692     21.1
# 33    16.525043     19.0
# 34    14.784183     17.2
# 35    14.494636     17.6
# 36    13.726697     10.7
# 37    10.551844     10.3
# 38     9.740218     11.1
# 39     9.410541      9.8
# 40     7.742004      7.1
# 41     6.900398      6.1
# 42     6.140970      6.7
# 43     6.180344      8.6
# 44     7.963865      7.2
# 45     7.517075      4.2
# 46     5.937706     10.5
# 47     7.748971     10.9
# 48     8.556049     10.8
# 49     7.683732      7.7
# 50     8.934854      7.6
# 51     9.003318     10.5

# %%
plt.plot(df_inverted['Predictions'])
plt.plot(df_inverted['Actuals'])
plt.title('Predictions for PM10')
plt.legend(['Predictions', 'Actuals'])
plt.savefig('predicts.png')

# %%
df_inverted.describe()
# Out:
#        Predictions    Actuals
# count    52.000000  52.000000
# mean     11.615685  11.407692
# std       3.424712   4.813903
# min       5.937706   4.200000
# 25%       8.986202   7.775000
# 50%      11.081864  10.400000
# 75%      14.330673  14.750000
# max      17.854692  22.000000

# %% [markdown]
# # NO2 Predictions

# %%
traffic = pd.read_csv('traffic.csv')
traffic_gr= traffic.groupby(['roundedTimestamp', 'Bezeichnung']).sum()
traffic_gr = traffic_gr.reset_index()
traffic_gr
sum_vehicles_list = []

for i, row in traffic_gr.iterrows():
    sum_vehicles = row[2:67].sum()
    sum_vehicles_list.append(sum_vehicles)

traffic_gr['SumVehicles'] = sum_vehicles_list
data = {'intersection' : traffic_gr['Bezeichnung'], 'timestamp' : traffic_gr['roundedTimestamp'], 'sum_vehicles': sum_vehicles_list}
traffic_sum = pd.DataFrame(data = data)
traffic_sum
traffic_sum_total = traffic_sum.groupby('timestamp')['sum_vehicles'].sum()
traffic_sum_total = pd.DataFrame(traffic_sum_total).reset_index()
traffic_sum_total
pred_data1 = traffic_sum_total.merge(weather, how='left', left_on= 'timestamp', right_on='datetime').merge(emissions[['PM10', 'PM2,5', 'NO2', 'datetime']], how='left', left_on= 'timestamp', right_on='datetime' )
pred_data1.drop(columns=['datetime_y', 'datetime_x'], inplace = True)
show(pred_data1)

df_sum = pred_data1.copy()
df_sum.index = pd.to_datetime(df_sum['timestamp'], format='%Y-%m-%d %H:%M:%S')
df_sum[:26]
df_sum['Seconds'] = df_sum.index.map(pd.Timestamp.timestamp)
df_sum
day = 60*60*24
year = 365.2425*day

df_sum['Day sin'] = np.sin(df_sum['Seconds'] * (2* np.pi / day))
df_sum['Day cos'] = np.cos(df_sum['Seconds'] * (2 * np.pi / day))
df_sum['Year sin'] = np.sin(df_sum['Seconds'] * (2 * np.pi / year))
df_sum['Year cos'] = np.cos(df_sum['Seconds'] * (2 * np.pi / year))
df_sum.head()

#drop unwanted columns
df_sum = df_sum.drop(columns = ['timestamp', 'Seconds'])
df_sum = df_sum.fillna(df_sum.mean())
df_sum


scaler_X = MinMaxScaler(feature_range=(0, 1))
scaler_y = MinMaxScaler(feature_range=(0, 1))

# Separate your DataFrame into features and target variable
X = df_sum.drop(columns=["NO2"])

y = df_sum[["NO2"]]

# Scale the features (X) and target (y) separately
X_scaled = scaler_X.fit_transform(X)
y_scaled = scaler_y.fit_transform(y)

# Create a new DataFrame with the scaled features and target variable
df_scaled = pd.DataFrame(data=X_scaled, columns=X.columns, index=df_sum.index)
df_scaled['NO2'] = y
print(df_scaled)

# #move target to be first column
column_to_move = df_scaled.pop('PM10')
df_scaled.insert(0, 'PM10', column_to_move)
df_scaled

def df_to_X_y2(df, window_size=6):
  df_as_np = df.to_numpy()
  X = []
  y = []
  for i in range(len(df_as_np)-window_size):
    row = [r for r in df_as_np[i:i+window_size]]
    X.append(row)
    #define y
    label = [df_as_np[i+window_size]]
    y.append(label)
  return np.array(X), np.array(y)
X5, y5 = df_to_X_y2(df_scaled)
X5.shape, y5.shape

#split data
X5_train, y5_train = X5[:300], y5[:300]
X5_val, y5_val = X5[300:350], y5[300:350]
X5_test, y5_test = X5[350:], y5[350:]
X5_train.shape, y5_train.shape, X5_val.shape, y5_val.shape, X5_test.shape, y5_test.shape

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adagrad, Adam
from tensorflow.keras.regularizers import l1
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.metrics import MeanAbsoluteError, RootMeanSquaredError
from tensorflow.keras.backend import clear_session

# Clear the Keras session
clear_session()

# Set up checkpoint to save the best model
cp5 = ModelCheckpoint('model_no2/', save_best_only=True)

# Create the model
model_no2 = Sequential()

# Input layer
model_no2.add(InputLayer((6,13)))

model_no2.add(LSTM(64))
model_no2.add(Dropout(0.2))

# Decrease the number of neurons in Dense layers and add L1-Regularization
model_no2.add(Dense(64, activation='relu'))#, kernel_regularizer=l1(0.001)))
model_no2.add(Dense(16, activation='relu'))#, kernel_regularizer=l1(0.001)))


model_no2.add(Dense(1, activation='linear'))

#model5.compile(loss='mean_absolute_error', optimizer=Adagrad(learning_rate=1), metrics=[RootMeanSquaredError()])
model_no2.compile(loss='mean_absolute_error', optimizer=Adam(learning_rate=0.001), metrics=['mean_squared_error'])

# Display model summary
model_no2.summary()

#fit model
model_no2.fit(X5_train, y5_train, validation_data=(X5_val, y5_val), epochs=20, callbacks=[cp5])
from tensorflow.keras.models import load_model
model_no2 = load_model('model_no2/')
# prdiction for one target value


from sklearn.metrics import mean_squared_error as mse

def plot_predictions_no2(model, X, y, start=0, end=100):
  predictions = model.predict(X).flatten()
  df = pd.DataFrame(data={'Predictions':predictions, 'Actuals':y_scaled})
  plt.plot(df['Predictions'][start:end])
  plt.plot(df['Actuals'][start:end])
  return df, mse(y, predictions)


model_no2.evaluate(X5_test, y5_test)
plot_predictions_no2(model_no2, X5_test, y5_test)

### Invert Prediction Values
# Reshape 'Predictions' and 'Actuals' to have one feature
predictions = df['Predictions'].values.reshape(-1, 1)
actuals = df['Actuals'].values.reshape(-1, 1)

predictions_inverted = scaler_y.inverse_transform(predictions)
actuals_inverted = scaler_y.inverse_transform(actuals)
df_inverted = pd.DataFrame({
    'Predictions': predictions_inverted.flatten(),
    'Actuals': actuals_inverted.flatten()
})
df_inverted
plt.plot(df_inverted['Predictions'])
plt.plot(df_inverted['Actuals'])
plt.title('Predictions for NO2')
plt.legend(['Predictions', 'Actuals'])
plt.savefig('predicts.png')

df_inverted.describe()
# Out:
# <style>.itables table td {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables table th {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables thead input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
#
# .itables tfoot input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
# </style>
# <div class="itables">
# <table id="72a59a4d-7a5a-42a6-8bb8-bd44b65ba20c" class="display nowrap"style="table-layout:auto;width:auto;margin:auto;caption-side:bottom"><thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>timestamp</th>
#       <th>sum_vehicles</th>
#       <th>Luftdruck[hPa]</th>
#       <th>Relative Luftfeuchtigkeit[%]</th>
#       <th>Temperatur[°C]</th>
#       <th>Windgeschwindigkeit[m/s]</th>
#       <th>Windrichtung[Grad]</th>
#       <th>PM10</th>
#       <th>PM2,5</th>
#       <th>NO2</th>
#     </tr>
#   </thead><tbody><tr><td>Loading... (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td></tr></tbody></table>
# <link rel="stylesheet" type="text/css" href="https://cdn.datatables.net/1.13.1/css/jquery.dataTables.min.css">
# <script type="module">
#     // Import jquery and DataTable
#     import 'https://code.jquery.com/jquery-3.6.0.min.js';
#     import dt from 'https://cdn.datatables.net/1.12.1/js/jquery.dataTables.mjs';
#     dt($);
#
#     // Define the table data
#     const data = [[0,
185
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
#  1/10 [==>...........................] - ETA: 31s - loss: 2.2046 - mean_squared_error: 52.6451
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# 10/10 [==============================] - 19s 2s/step - loss: 2.1977 - mean_squared_error: 61.4838 - val_loss: 1.2620 - val_mean_squared_error: 14.0242
# Epoch 2/20
#  6/10 [=================>............] - ETA: 0s - loss: 2.1278 - mean_squared_error: 58.5901
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# 10/10 [==============================] - 13s 1s/step - loss: 2.1483 - mean_squared_error: 60.7950 - val_loss: 1.2542 - val_mean_squared_error: 14.3387
# Epoch 3/20
#  1/10 [==>...........................] - ETA: 0s - loss: 2.3103 - mean_squared_error: 71.9694
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# 10/10 [==============================] - 13s 1s/step - loss: 2.1431 - mean_squared_error: 60.3107 - val_loss: 1.2519 - val_mean_squared_error: 14.2057
# Epoch 4/20
#  1/10 [==>...........................] - ETA: 0s - loss: 2.0603 - mean_squared_error: 50.5106
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\Data Science\VS Code\final_project\code_repository\time_series_prediction.ipynb Cell 90 line <cell line: 121>()
#     <a href='vscode-notebook-cell:/d%3A/Data%20Science/VS%20Code/final_project/code_repository/time_series_prediction.ipynb#Y161sZmlsZQ%3D%3D?line=117'>118</a> model_no2.summary()
#     <a href='vscode-notebook-cell:/d%3A/Data%20Science/VS%20Code/final_project/code_repository/time_series_prediction.ipynb#Y161sZmlsZQ%3D%3D?line=119'>120</a> #fit model
# --> <a href='vscode-notebook-cell:/d%3A/Data%20Science/VS%20Code/final_project/code_repository/time_series_prediction.ipynb#Y161sZmlsZQ%3D%3D?line=120'>121</a> model_no2.fit(X5_train, y5_train, validation_data=(X5_val, y5_val), epochs=20, callbacks=[cp5])
#     <a href='vscode-notebook-cell:/d%3A/Data%20Science/VS%20Code/final_project/code_repository/time_series_prediction.ipynb#Y161sZmlsZQ%3D%3D?line=121'>122</a> from tensorflow.keras.models import load_model
#     <a href='vscode-notebook-cell:/d%3A/Data%20Science/VS%20Code/final_project/code_repository/time_series_prediction.ipynb#Y161sZmlsZQ%3D%3D?line=122'>123</a> model_no2 = load_model('model_no2/')
#
# File c:\Users\cathr\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\cathr\anaconda3\lib\site-packages\keras\engine\training.py:1624, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1619     val_logs = {
#    1620         "val_" + name: val for name, val in val_logs.items()
#    1621     }
#    1622     epoch_logs.update(val_logs)
# -> 1624 callbacks.on_epoch_end(epoch, epoch_logs)
#    1625 training_logs = epoch_logs
#    1626 if self.stop_training:
#
# File c:\Users\cathr\anaconda3\lib\site-packages\keras\callbacks.py:448, in CallbackList.on_epoch_end(self, epoch, logs)
#     446 logs = self._process_logs(logs)
#     447 for callback in self.callbacks:
# --> 448     callback.on_epoch_end(epoch, logs)
#
# File c:\Users\cathr\anaconda3\lib\site-packages\keras\callbacks.py:1463, in ModelCheckpoint.on_epoch_end(self, epoch, logs)
#    1460 self.epochs_since_last_save += 1
#    1462 if self.save_freq == "epoch":
# -> 1463     self._save_model(epoch=epoch, batch=None, logs=logs)
#
# File c:\Users\cathr\anaconda3\lib\site-packages\keras\callbacks.py:1528, in ModelCheckpoint._save_model(self, epoch, batch, logs)
#    1522         self.model.save_weights(
#    1523             filepath,
#    1524             overwrite=True,
#    1525             options=self._options,
#    1526         )
#    1527     else:
# -> 1528         self.model.save(
#    1529             filepath,
#    1530             overwrite=True,
#    1531             options=self._options,
#    1532         )
#    1533 else:
#    1534     if self.verbose > 0:
#
# File c:\Users\cathr\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\cathr\anaconda3\lib\site-packages\keras\engine\training.py:2698, in Model.save(self, filepath, overwrite, include_optimizer, save_format, signatures, options, save_traces)
#    2643 @traceback_utils.filter_traceback
#    2644 def save(
#    2645     self,
#    (...)
#    2652     save_traces=True,
#    2653 ):
#    2655     """Saves the model to Tensorflow SavedModel or a single HDF5 file.
#    2656
#    2657     Please see `tf.keras.models.save_model` or the
#    (...)
#    2695     ```
#    2696     """
# -> 2698     save.save_model(
#    2699         self,
#    2700         filepath,
#    2701         overwrite,
#    2702         include_optimizer,
#    2703         save_format,
#    2704         signatures,
#    2705         options,
#    2706         save_traces,
#    2707     )
#
# File c:\Users\cathr\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\cathr\anaconda3\lib\site-packages\keras\saving\save.py:166, in save_model(model, filepath, overwrite, include_optimizer, save_format, signatures, options, save_traces)
#     164 else:
#     165     with generic_utils.SharedObjectSavingScope():
# --> 166         saved_model_save.save(
#     167             model,
#     168             filepath,
#     169             overwrite,
#     170             include_optimizer,
#     171             signatures,
#     172             options,
#     173             save_traces,
#     174         )
#
# File c:\Users\cathr\anaconda3\lib\site-packages\keras\saving\saved_model\save.py:97, in save(model, filepath, overwrite, include_optimizer, signatures, options, save_traces)
#      95 with backend.deprecated_internal_learning_phase_scope(0):
#      96     with utils.keras_option_scope(save_traces):
# ---> 97         saved_nodes, node_paths = save_lib.save_and_return_nodes(
#      98             model, filepath, signatures, options
#      99         )
#     101     # Save all metadata to a separate file in the SavedModel directory.
#     102     metadata = generate_keras_metadata(saved_nodes, node_paths)
#
# File c:\Users\cathr\anaconda3\lib\site-packages\tensorflow\python\saved_model\save.py:1299, in save_and_return_nodes(obj, export_dir, signatures, options, experimental_skip_checkpoint)
#    1295 # We will slowly migrate code in this function to pywrap_saved_model.Save
#    1296 # as we build up the C++ API.
#    1297 pywrap_saved_model.Save(export_dir)
# -> 1299 saved_model_serialized = saved_model.SerializeToString(deterministic=True)
#    1301 # Write fingerprint protobuf, if requested.
#    1302 if flags.config().saved_model_fingerprinting.value():
#
# File c:\Users\cathr\anaconda3\lib\site-packages\google\protobuf\internal\python_message.py:1086, in _AddSerializeToStringMethod.<locals>.SerializeToString(self, **kwargs)
#    1082 if not self.IsInitialized():
#    1083   raise message_mod.EncodeError(
#    1084       'Message %s is missing required fields: %s' % (
#    1085       self.DESCRIPTOR.full_name, ','.join(self.FindInitializationErrors())))
# -> 1086 return self.SerializePartialToString(**kwargs)
#
# File c:\Users\cathr\anaconda3\lib\site-packages\google\protobuf\internal\python_message.py:1095, in _AddSerializePartialToStringMethod.<locals>.SerializePartialToString(self, **kwargs)
#    1093 def SerializePartialToString(self, **kwargs):
#    1094   out = BytesIO()
# -> 1095   self._InternalSerialize(out.write, **kwargs)
#    1096   return out.getvalue()
#
# File c:\Users\cathr\anaconda3\lib\site-packages\google\protobuf\internal\python_message.py:1115, in _AddSerializePartialToStringMethod.<locals>.InternalSerialize(self, write_bytes, deterministic)
#    1113 else:
#    1114   for field_descriptor, field_value in self.ListFields():
# -> 1115     field_descriptor._encoder(write_bytes, field_value, deterministic)
#    1116   for tag_bytes, value_bytes in self._unknown_fields:
#    1117     write_bytes(tag_bytes)
#
# File c:\Users\cathr\anaconda3\lib\site-packages\google\protobuf\internal\encoder.py:762, in MessageEncoder.<locals>.EncodeRepeatedField(write, value, deterministic)
#     760 write(tag)
#     761 local_EncodeVarint(write, element.ByteSize(), deterministic)
# --> 762 element._InternalSerialize(write, deterministic)
#
# File c:\Users\cathr\anaconda3\lib\site-packages\google\protobuf\internal\python_message.py:1115, in _AddSerializePartialToStringMethod.<locals>.InternalSerialize(self, write_bytes, deterministic)
#    1113 else:
#    1114   for field_descriptor, field_value in self.ListFields():
# -> 1115     field_descriptor._encoder(write_bytes, field_value, deterministic)
#    1116   for tag_bytes, value_bytes in self._unknown_fields:
#    1117     write_bytes(tag_bytes)
#
# File c:\Users\cathr\anaconda3\lib\site-packages\google\protobuf\internal\encoder.py:768, in MessageEncoder.<locals>.EncodeField(write, value, deterministic)
#     766 write(tag)
#     767 local_EncodeVarint(write, value.ByteSize(), deterministic)
# --> 768 return value._InternalSerialize(write, deterministic)
#
# File c:\Users\cathr\anaconda3\lib\site-packages\google\protobuf\internal\python_message.py:1115, in _AddSerializePartialToStringMethod.<locals>.InternalSerialize(self, write_bytes, deterministic)
#    1113 else:
#    1114   for field_descriptor, field_value in self.ListFields():
# -> 1115     field_descriptor._encoder(write_bytes, field_value, deterministic)
#    1116   for tag_bytes, value_bytes in self._unknown_fields:
#    1117     write_bytes(tag_bytes)
#
# File c:\Users\cathr\anaconda3\lib\site-packages\google\protobuf\internal\encoder.py:768, in MessageEncoder.<locals>.EncodeField(write, value, deterministic)
#     766 write(tag)
#     767 local_EncodeVarint(write, value.ByteSize(), deterministic)
# --> 768 return value._InternalSerialize(write, deterministic)
#
# File c:\Users\cathr\anaconda3\lib\site-packages\google\protobuf\internal\python_message.py:1115, in _AddSerializePartialToStringMethod.<locals>.InternalSerialize(self, write_bytes, deterministic)
#    1113 else:
#    1114   for field_descriptor, field_value in self.ListFields():
# -> 1115     field_descriptor._encoder(write_bytes, field_value, deterministic)
#    1116   for tag_bytes, value_bytes in self._unknown_fields:
#    1117     write_bytes(tag_bytes)
#
# File c:\Users\cathr\anaconda3\lib\site-packages\google\protobuf\internal\encoder.py:762, in MessageEncoder.<locals>.EncodeRepeatedField(write, value, deterministic)
#     760 write(tag)
#     761 local_EncodeVarint(write, element.ByteSize(), deterministic)
# --> 762 element._InternalSerialize(write, deterministic)
#
# File c:\Users\cathr\anaconda3\lib\site-packages\google\protobuf\internal\python_message.py:1115, in _AddSerializePartialToStringMethod.<locals>.InternalSerialize(self, write_bytes, deterministic)
#    1113 else:
#    1114   for field_descriptor, field_value in self.ListFields():
# -> 1115     field_descriptor._encoder(write_bytes, field_value, deterministic)
#    1116   for tag_bytes, value_bytes in self._unknown_fields:
#    1117     write_bytes(tag_bytes)
#
# File c:\Users\cathr\anaconda3\lib\site-packages\google\protobuf\internal\encoder.py:827, in MapEncoder.<locals>.EncodeField(write, value, deterministic)
#     825 for key in value_keys:
#     826   entry_msg = message_type._concrete_class(key=key, value=value[key])
# --> 827   encode_message(write, entry_msg, deterministic)
#
# File c:\Users\cathr\anaconda3\lib\site-packages\google\protobuf\internal\encoder.py:767, in MessageEncoder.<locals>.EncodeField(write, value, deterministic)
#     765 def EncodeField(write, value, deterministic):
#     766   write(tag)
# --> 767   local_EncodeVarint(write, value.ByteSize(), deterministic)
#     768   return value._InternalSerialize(write, deterministic)
#
# File c:\Users\cathr\anaconda3\lib\site-packages\google\protobuf\internal\python_message.py:1062, in _AddByteSizeMethod.<locals>.ByteSize(self)
#    1059 if descriptor.GetOptions().map_entry:
#    1060   # Fields of map entry should always be serialized.
#    1061   size = descriptor.fields_by_name['key']._sizer(self.key)
# -> 1062   size += descriptor.fields_by_name['value']._sizer(self.value)
#    1063 else:
#    1064   for field_descriptor, field_value in self.ListFields():
#
# File c:\Users\cathr\anaconda3\lib\site-packages\google\protobuf\internal\encoder.py:306, in MessageSizer.<locals>.FieldSize(value)
#     305 def FieldSize(value):
# --> 306   l = value.ByteSize()
#     307   return tag_size + local_VarintSize(l) + l
#
# File c:\Users\cathr\anaconda3\lib\site-packages\google\protobuf\internal\python_message.py:1065, in _AddByteSizeMethod.<locals>.ByteSize(self)
#    1063 else:
#    1064   for field_descriptor, field_value in self.ListFields():
# -> 1065     size += field_descriptor._sizer(field_value)
#    1066   for tag_bytes, value_bytes in self._unknown_fields:
#    1067     size += len(tag_bytes) + len(value_bytes)
#
# File c:\Users\cathr\anaconda3\lib\site-packages\google\protobuf\internal\encoder.py:359, in MapSizer.<locals>.FieldSize(map_value)
#     353 # It's wasteful to create the messages and throw them away one second
#     354 # later since we'll do the same for the actual encode.  But there's not an
#     355 # obvious way to avoid this within the current design without tons of code
#     356 # duplication. For message map, value.ByteSize() should be called to
#     357 # update the status.
#     358 entry_msg = message_type._concrete_class(key=key, value=value)
# --> 359 total += message_sizer(entry_msg)
#     360 if is_message_map:
#     361   value.ByteSize()
#
# File c:\Users\cathr\anaconda3\lib\site-packages\google\protobuf\internal\encoder.py:306, in MessageSizer.<locals>.FieldSize(value)
#     305 def FieldSize(value):
# --> 306   l = value.ByteSize()
#     307   return tag_size + local_VarintSize(l) + l
#
# File c:\Users\cathr\anaconda3\lib\site-packages\google\protobuf\internal\python_message.py:1062, in _AddByteSizeMethod.<locals>.ByteSize(self)
#    1059 if descriptor.GetOptions().map_entry:
#    1060   # Fields of map entry should always be serialized.
#    1061   size = descriptor.fields_by_name['key']._sizer(self.key)
# -> 1062   size += descriptor.fields_by_name['value']._sizer(self.value)
#    1063 else:
#    1064   for field_descriptor, field_value in self.ListFields():
#
# File c:\Users\cathr\anaconda3\lib\site-packages\google\protobuf\internal\encoder.py:306, in MessageSizer.<locals>.FieldSize(value)
#     305 def FieldSize(value):
# --> 306   l = value.ByteSize()
#     307   return tag_size + local_VarintSize(l) + l
#
# File c:\Users\cathr\anaconda3\lib\site-packages\google\protobuf\internal\python_message.py:1065, in _AddByteSizeMethod.<locals>.ByteSize(self)
#    1063 else:
#    1064   for field_descriptor, field_value in self.ListFields():
# -> 1065     size += field_descriptor._sizer(field_value)
#    1066   for tag_bytes, value_bytes in self._unknown_fields:
#    1067     size += len(tag_bytes) + len(value_bytes)
#
# File c:\Users\cathr\anaconda3\lib\site-packages\google\protobuf\internal\encoder.py:306, in MessageSizer.<locals>.FieldSize(value)
#     305 def FieldSize(value):
# --> 306   l = value.ByteSize()
#     307   return tag_size + local_VarintSize(l) + l
#
# File c:\Users\cathr\anaconda3\lib\site-packages\google\protobuf\internal\python_message.py:1065, in _AddByteSizeMethod.<locals>.ByteSize(self)
#    1063 else:
#    1064   for field_descriptor, field_value in self.ListFields():
# -> 1065     size += field_descriptor._sizer(field_value)
#    1066   for tag_bytes, value_bytes in self._unknown_fields:
#    1067     size += len(tag_bytes) + len(value_bytes)
#
# File c:\Users\cathr\anaconda3\lib\site-packages\google\protobuf\internal\encoder.py:300, in MessageSizer.<locals>.RepeatedFieldSize(value)
#     298 result = tag_size * len(value)
#     299 for element in value:
# --> 300   l = element.ByteSize()
#     301   result += local_VarintSize(l) + l
#     302 return result
#
# File c:\Users\cathr\anaconda3\lib\site-packages\google\protobuf\internal\python_message.py:1065, in _AddByteSizeMethod.<locals>.ByteSize(self)
#    1063 else:
#    1064   for field_descriptor, field_value in self.ListFields():
# -> 1065     size += field_descriptor._sizer(field_value)
#    1066   for tag_bytes, value_bytes in self._unknown_fields:
#    1067     size += len(tag_bytes) + len(value_bytes)
#
# File c:\Users\cathr\anaconda3\lib\site-packages\google\protobuf\internal\encoder.py:298, in MessageSizer.<locals>.RepeatedFieldSize(value)
#     297 def RepeatedFieldSize(value):
# --> 298   result = tag_size * len(value)
#     299   for element in value:
#     300     l = element.ByteSize()
#
# File c:\Users\cathr\anaconda3\lib\site-packages\google\protobuf\internal\containers.py:97, in BaseContainer.__len__(self)
#      95 def __len__(self) -> int:
#      96   """Returns the number of elements in the container."""
# ---> 97   return len(self._values)
#
# KeyboardInterrupt:

# %%
model_no2.evaluate(X5_test, y5_test)
# Out:
# 2/2 [==============================] - 0s 13ms/step - loss: 1.2213 - mean_squared_error: 15.2011
# [1.2213366031646729, 15.201141357421875]

# %%
y_scaled
# Out:
# array([[0.40705563],
#        [0.54545455],
#        [0.49389417],
#        [0.1614654 ],
#        [0.20895522],
#        [0.16824966],
#        [0.38941655],
#        [0.37177748],
#        [0.40434193],
#        [0.16960651],
#        [0.18453189],
#        [0.17232022],
#        [0.44776119],
#        [0.37042062],
#        [0.40976934],
#        [0.10719132],
#        [0.12347354],
#        [0.13432836],
#        [0.1614654 ],
#        [0.16824966],
#        [0.55088195],
#        [0.59972863],
#        [0.53052917],
#        [0.31886024],
#        [0.27815468],
#        [0.30664858],
#        [0.26322931],
#        [0.19131615],
#        [0.28765265],
#        [0.39755767],
#        [0.3256445 ],
#        [0.25373134],
#        [0.40841248],
#        [0.25439477],
#        [0.18046133],
#        [0.16282225],
#        [0.10854817],
#        [0.33107191],
#        [0.38127544],
#        [0.35006784],
#        [0.09769335],
#        [0.08683853],
#        [0.07327001],
#        [0.39891452],
#        [0.49660787],
#        [0.55359566],
#        [0.29715061],
#        [0.33921303],
#        [0.35142469],
#        [0.42740841],
#        [0.39620081],
#        [0.36092266],
#        [0.4165536 ],
#        [0.30393487],
#        [0.29443691],
#        [0.28765265],
#        [0.28765265],
#        [0.16282225],
#        [0.13432836],
#        [0.0990502 ],
#        [0.19131615],
#        [0.18181818],
#        [0.16553596],
#        [0.18860244],
#        [0.21573948],
#        [0.10176391],
#        [0.10040706],
#        [0.14654003],
#        [0.20352782],
#        [0.18995929],
#        [0.21709634],
#        [0.54138399],
#        [0.46404342],
#        [0.36227951],
#        [0.20081411],
#        [0.26458616],
#        [0.18995929],
#        [0.51424695],
#        [0.44504749],
#        [0.56445047],
#        [0.18317503],
#        [0.20081411],
#        [0.26594301],
#        [0.23744912],
#        [0.22930801],
#        [0.18995929],
#        [0.19131615],
#        [0.18860244],
#        [0.40841248],
#        [0.3880597 ],
#        [0.41791045],
#        [0.33785617],
#        [0.27951153],
#        [0.33378562],
#        [0.33107191],
#        [0.30936228],
#        [0.192673  ],
#        [0.25101764],
#        [0.20081411],
#        [0.23473541],
#        [0.27001357],
#        [0.27679783],
#        [0.31071913],
#        [0.30122117],
#        [0.30800543],
#        [0.28086839],
#        [0.28493894],
#        [0.16689281],
#        [0.1302578 ],
#        [0.14925373],
#        [0.16282225],
#        [0.16689281],
#        [0.26729986],
#        [0.23202171],
#        [0.24966079],
#        [0.25915875],
#        [0.28222524],
#        [0.28358209],
#        [0.385346  ],
#        [0.32971506],
#        [0.26322931],
#        [0.35956581],
#        [0.42062415],
#        [0.36635007],
#        [0.29579376],
#        [0.35820896],
#        [0.38670285],
#        [0.36227951],
#        [0.36363636],
#        [0.34192673],
#        [0.3256445 ],
#        [0.34464043],
#        [0.14111262],
#        [0.1302578 ],
#        [0.15739484],
#        [0.26594301],
#        [0.21166893],
#        [0.22795115],
#        [0.11940299],
#        [0.0963365 ],
#        [0.10312076],
#        [0.12211669],
#        [0.1275441 ],
#        [0.12483039],
#        [0.13568521],
#        [0.11397558],
#        [0.2917232 ],
#        [0.32971506],
#        [0.25101764],
#        [0.10312076],
#        [0.10447761],
#        [0.12483039],
#        [0.30529172],
#        [0.36906377],
#        [0.31886024],
#        [0.17096336],
#        [0.17774763],
#        [0.18588874],
#        [0.35142469],
#        [0.44640434],
#        [0.47218453],
#        [0.41383989],
#        [0.45861601],
#        [0.42469471],
#        [0.44911805],
#        [0.50203528],
#        [0.2265943 ],
#        [0.23609227],
#        [0.21981004],
#        [0.37313433],
#        [0.42469471],
#        [0.44911805],
#        [0.22523745],
#        [0.18860244],
#        [0.19131615],
#        [0.21845319],
#        [0.17639077],
#        [0.21845319],
#        [0.36227951],
#        [0.42333786],
#        [0.4165536 ],
#        [0.47354138],
#        [0.51153324],
#        [0.41383989],
#        [0.59701493],
#        [0.6770692 ],
#        [0.63636364],
#        [0.71370421],
#        [0.72998643],
#        [0.26458616],
#        [0.31343284],
#        [0.33378562],
#        [0.78426052],
#        [0.77747626],
#        [0.63364993],
#        [0.35006784],
#        [0.31343284],
#        [0.33785617],
#        [0.41112619],
#        [0.50067843],
#        [0.86295794],
#        [0.78561737],
#        [0.74898236],
#        [0.27137042],
#        [0.22795115],
#        [0.18046133],
#        [0.38127544],
#        [0.50474898],
#        [0.44369064],
#        [0.37584803],
#        [0.39620081],
#        [0.49525102],
#        [0.26322931],
#        [0.27815468],
#        [0.2578019 ],
#        [0.22795115],
#        [0.19810041],
#        [0.20895522],
#        [0.23609227],
#        [0.17232022],
#        [0.16553596],
#        [0.67842605],
#        [0.7761194 ],
#        [0.66757123],
#        [0.33107191],
#        [0.34599729],
#        [0.44776119],
#        [0.55766621],
#        [0.85753053],
#        [0.88059701],
#        [0.75440977],
#        [0.74084125],
#        [1.        ],
#        [0.54138399],
#        [0.56852103],
#        [0.57530529],
#        [0.18860244],
#        [0.17910448],
#        [0.1587517 ],
#        [0.25644505],
#        [0.2238806 ],
#        [0.27951153],
#        [0.08955224],
#        [0.08548168],
#        [0.10040706],
#        [0.05427408],
#        [0.03799186],
#        [0.05970149],
#        [0.75169607],
#        [0.61329715],
#        [0.578019  ],
#        [0.10176391],
#        [0.0963365 ],
#        [0.17367707],
#        [0.20624152],
#        [0.17910448],
#        [0.19402985],
#        [0.57394844],
#        [0.43554953],
#        [0.44369064],
#        [0.16553596],
#        [0.14382632],
#        [0.14382632],
#        [0.1587517 ],
#        [0.10990502],
#        [0.12211669],
#        [0.15739484],
#        [0.13161465],
#        [0.12211669],
#        [0.23202171],
#        [0.27679783],
#        [0.31478969],
#        [0.15603799],
#        [0.14654003],
#        [0.17774763],
#        [0.08412483],
#        [0.11126187],
#        [0.0936228 ],
#        [0.07327001],
#        [0.02985075],
#        [0.22252374],
#        [0.21845319],
#        [0.17367707],
#        [0.22523745],
#        [0.14789688],
#        [0.15061058],
#        [0.18317503],
#        [0.20217096],
#        [0.14789688],
#        [0.22523745],
#        [0.10447761],
#        [0.13568521],
#        [0.07462687],
#        [0.09090909],
#        [0.08819539],
#        [0.0624152 ],
#        [0.08005427],
#        [0.05834464],
#        [0.17774763],
#        [0.13839891],
#        [0.13975577],
#        [0.05291723],
#        [0.05698779],
#        [0.05020353],
#        [0.04477612],
#        [0.05427408],
#        [0.01763908],
#        [0.01492537],
#        [0.03934871],
#        [0.02306649],
#        [0.0339213 ],
#        [0.04070556],
#        [0.04748982],
#        [0.0312076 ],
#        [0.0339213 ],
#        [0.07598372],
#        [0.07327001],
#        [0.07462687],
#        [0.0651289 ],
#        [0.1302578 ],
#        [0.08683853],
#        [0.09769335],
#        [0.15332429],
#        [0.14382632],
#        [0.08819539],
#        [0.14382632],
#        [0.18317503],
#        [0.07869742],
#        [0.08005427],
#        [0.07327001],
#        [0.14789688],
#        [0.16282225],
#        [0.21981004],
#        [0.21438263],
#        [0.08819539],
#        [0.08955224],
#        [0.07869742],
#        [0.24966079],
#        [0.20352782],
#        [0.18453189],
#        [0.24151967],
#        [0.15739484],
#        [0.24016282],
#        [0.25915875],
#        [0.30393487],
#        [0.38941655],
#        [0.30936228],
#        [0.22116689],
#        [0.21031208],
#        [0.18860244],
#        [0.20759837],
#        [0.17367707],
#        [0.08683853],
#        [0.10176391],
#        [0.08683853],
#        [0.17096336],
#        [0.15061058],
#        [0.11261872],
#        [0.08683853],
#        [0.16010855],
#        [0.04206242],
#        [0.12075984],
#        [0.13704206],
#        [0.14246947],
#        [0.11261872],
#        [0.07869742],
#        [0.07598372],
#        [0.08683853],
#        [0.01492537],
#        [0.27679783],
#        [0.1641791 ],
#        [0.01763908],
#        [0.08548168],
#        [0.07462687],
#        [0.        ],
#        [0.15603799],
#        [0.14518318],
#        [0.19402985],
#        [0.21302578],
#        [0.16960651],
#        [0.1587517 ],
#        [0.04884668],
#        [0.02713704],
#        [0.08548168],
#        [0.30936228],
#        [0.32428765],
#        [0.10583446],
#        [0.13704206],
#        [0.18046133],
#        [0.06377205],
#        [0.22252374],
#        [0.29986431],
#        [0.04477612],
#        [0.36092266],
#        [0.34464043],
#        [0.17367707],
#        [0.10447761],
#        [0.07869742],
#        [0.03256445],
#        [0.11533243],
#        [0.05156038],
#        [0.12483039],
#        [0.06377205],
#        [0.06377205],
#        [0.09226594],
#        [0.13704206],
#        [0.10312076],
#        [0.07191316]])

# %%
  predictions = model_no2.predict(X5_test).flatten()
  predictions
# Out:
# 2/2 [==============================] - 1s 4ms/step
# array([0.39489594, 0.3919369 , 0.3864199 , 0.38327828, 0.3989609 ,
#        0.37143514, 0.38866597, 0.3914678 , 0.39280832, 0.39129168,
#        0.38386366, 0.38862395, 0.39220142, 0.363008  , 0.38837725,
#        0.3839672 , 0.35231188, 0.36899325, 0.37219903, 0.35975185,
#        0.3789525 , 0.3791597 , 0.38967845, 0.39019668, 0.38562325,
#        0.39565033, 0.37237075, 0.36640492, 0.38109997, 0.38829815,
#        0.38191646, 0.35862264, 0.3744055 , 0.39254963, 0.37432113,
#        0.3974858 , 0.3930549 , 0.35477805, 0.38604325, 0.3877738 ,
#        0.37906808, 0.3760831 , 0.3800157 , 0.37442803, 0.39482772,
#        0.37888357, 0.39273268, 0.3826909 , 0.3839373 , 0.39622152,
#        0.40049493, 0.3977729 ], dtype=float32)

# %%
from sklearn.metrics import mean_squared_error as mse

def plot_predictions_no2(model, X, y, start=0, end=100):
  predictions = model.predict(X).flatten()
  df = pd.DataFrame(data={'Predictions':predictions, 'Actuals':y_scaled})
  plt.plot(df['Predictions'][start:end])
  plt.plot(df['Actuals'][start:end])
  return df, mse(y, predictions)

# %%
model_no2.evaluate(X5_test, y5_test)
plot_predictions_no2(model_no2, X5_test, y5_test)
# Out:
# 2/2 [==============================] - 0s 4ms/step - loss: 1.2213 - mean_squared_error: 15.2011
# 2/2 [==============================] - 0s 9ms/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\Data Science\VS Code\final_project\code_repository\time_series_prediction.ipynb Cell 95 line <cell line: 2>()
#       <a href='vscode-notebook-cell:/d%3A/Data%20Science/VS%20Code/final_project/code_repository/time_series_prediction.ipynb#Y165sZmlsZQ%3D%3D?line=0'>1</a> model_no2.evaluate(X5_test, y5_test)
# ----> <a href='vscode-notebook-cell:/d%3A/Data%20Science/VS%20Code/final_project/code_repository/time_series_prediction.ipynb#Y165sZmlsZQ%3D%3D?line=1'>2</a> plot_predictions_no2(model_no2, X5_test, y5_test)
#
# d:\Data Science\VS Code\final_project\code_repository\time_series_prediction.ipynb Cell 95 line plot_predictions_no2(model, X, y, start, end)
#       <a href='vscode-notebook-cell:/d%3A/Data%20Science/VS%20Code/final_project/code_repository/time_series_prediction.ipynb#Y165sZmlsZQ%3D%3D?line=2'>3</a> def plot_predictions_no2(model, X, y, start=0, end=100):
#       <a href='vscode-notebook-cell:/d%3A/Data%20Science/VS%20Code/final_project/code_repository/time_series_prediction.ipynb#Y165sZmlsZQ%3D%3D?line=3'>4</a>   predictions = model.predict(X).flatten()
# ----> <a href='vscode-notebook-cell:/d%3A/Data%20Science/VS%20Code/final_project/code_repository/time_series_prediction.ipynb#Y165sZmlsZQ%3D%3D?line=4'>5</a>   df = pd.DataFrame(data={'Predictions':predictions, 'Actuals':y_scaled})
#       <a href='vscode-notebook-cell:/d%3A/Data%20Science/VS%20Code/final_project/code_repository/time_series_prediction.ipynb#Y165sZmlsZQ%3D%3D?line=5'>6</a>   plt.plot(df['Predictions'][start:end])
#       <a href='vscode-notebook-cell:/d%3A/Data%20Science/VS%20Code/final_project/code_repository/time_series_prediction.ipynb#Y165sZmlsZQ%3D%3D?line=6'>7</a>   plt.plot(df['Actuals'][start:end])
#
# File c:\Users\cathr\anaconda3\lib\site-packages\pandas\core\frame.py:664, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     658     mgr = self._init_mgr(
#     659         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     660     )
#     662 elif isinstance(data, dict):
#     663     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 664     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     665 elif isinstance(data, ma.MaskedArray):
#     666     import numpy.ma.mrecords as mrecords
#
# File c:\Users\cathr\anaconda3\lib\site-packages\pandas\core\internals\construction.py:493, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     489     else:
#     490         # dtype check to exclude e.g. range objects, scalars
#     491         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 493 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File c:\Users\cathr\anaconda3\lib\site-packages\pandas\core\internals\construction.py:118, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     115 if verify_integrity:
#     116     # figure out the index, if necessary
#     117     if index is None:
# --> 118         index = _extract_index(arrays)
#     119     else:
#     120         index = ensure_index(index)
#
# File c:\Users\cathr\anaconda3\lib\site-packages\pandas\core\internals\construction.py:653, in _extract_index(data)
#     651         raw_lengths.append(len(val))
#     652     elif isinstance(val, np.ndarray) and val.ndim > 1:
# --> 653         raise ValueError("Per-column arrays must each be 1-dimensional")
#     655 if not indexes and not raw_lengths:
#     656     raise ValueError("If using all scalar values, you must pass an index")
#
# ValueError: Per-column arrays must each be 1-dimensional

# %%
### Invert Prediction Values
# Reshape 'Predictions' and 'Actuals' to have one feature
predictions = df['Predictions'].values.reshape(-1, 1)
actuals = df['Actuals'].values.reshape(-1, 1)

predictions_inverted = scaler_y.inverse_transform(predictions)
actuals_inverted = scaler_y.inverse_transform(actuals)
df_inverted = pd.DataFrame({
    'Predictions': predictions_inverted.flatten(),
    'Actuals': actuals_inverted.flatten()
})
df_inverted
plt.plot(df_inverted['Predictions'])
plt.plot(df_inverted['Actuals'])
plt.title('Predictions for NO2')
plt.legend(['Predictions', 'Actuals'])
plt.savefig('predicts.png')

df_inverted.describe()
